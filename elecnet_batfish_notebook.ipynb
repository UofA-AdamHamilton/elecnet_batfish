# %% [markdown]
# # trying to operate batfish with these config files

# %% [markdown]
# # Import packages
# %run startup.py
# bf = Session(host="localhost")

# %%
# if you need to reinstall pybatfish
install_packages = False
if install_packages:
    # !pip install pybatfish
    # !pip install tqdm

# %%
# Importing required libraries, setting up logging, and loading questions
import logging
import random  # noqa: F401
from typing import List, Optional  # noqa: F401

import pandas as pd
from IPython.display import display
from pandas.io.formats.style import Styler

from pybatfish.client.session import Session  # noqa: F401

# noinspection PyUnresolvedReferences
from pybatfish.datamodel import Edge, Interface  # noqa: F401
from pybatfish.datamodel.answer import TableAnswer
from pybatfish.datamodel.flow import HeaderConstraints, PathConstraints  # noqa: F401
from pybatfish.datamodel.route import BgpRoute  # noqa: F401
from pybatfish.util import get_html

# Configure all pybatfish loggers to use WARN level
logging.getLogger("pybatfish").setLevel(logging.WARN)

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
# Prevent rendering text between '$' as MathJax expressions
pd.set_option("display.html.use_mathjax", False)

# UUID for CSS styles used by pandas styler.
# Keeps our notebook HTML deterministic when displaying dataframes
_STYLE_UUID = "pybfstyle"


class MyStyler(Styler):
    """A custom styler for displaying DataFrames in HTML"""

    def __repr__(self):
        return repr(self.data)


def show(df):
    """
    Displays a dataframe as HTML table.

    Replaces newlines and double-spaces in the input with HTML markup, and
    left-aligns the text.
    """
    if isinstance(df, TableAnswer):
        df = df.frame()

    # workaround for Pandas bug in Python 2.7 for empty frames
    if not isinstance(df, pd.DataFrame) or df.size == 0:
        display(df)
        return
    display(
        MyStyler(df)
        .set_uuid(_STYLE_UUID)
        .format(get_html)
        .set_properties(**{"text-align": "left", "vertical-align": "top"})
    )

# %%
# Import packages

bf = Session(host="localhost")

# %%
# Assign a friendly name to your network and snapshot
NETWORK_NAME = "example_notwork"
SNAPSHOT_NAME = "example_snipshot"

# this is the path to the network. You need to spell it correctly
SNAPSHOT_PATH = "networks/elecnet"

# Now create the network and initialize the snapshot
bf.set_network(NETWORK_NAME)
bf.init_snapshot(SNAPSHOT_PATH, name=SNAPSHOT_NAME, overwrite=True)
# Out:
# 'example_snipshot'

# %%
parse_status = bf.q.fileParseStatus().answer().frame()

# %%
for i in range(len(parse_status)):
    print(parse_status.iloc[i])
    print(' ')
# Out:
# File_Name       configs/adlcore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['adlcore-1']
# Name: 0, dtype: object
#
# File_Name       configs/adlcore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['adlcore-2']
# Name: 1, dtype: object
#
# File_Name       configs/bnecore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['bnecore-1']
# Name: 2, dtype: object
#
# File_Name       configs/bnecore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['bnecore-2']
# Name: 3, dtype: object
#
# File_Name          configs/brd-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['brd-gw']
# Name: 4, dtype: object
#
# File_Name       configs/brwnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['brwnodegw']
# Name: 5, dtype: object
#
# File_Name          configs/byo-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['byo-gw']
# Name: 6, dtype: object
#
# File_Name      configs/cbpdnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                  ['cbpdnodegw']
# Name: 7, dtype: object
#
# File_Name       configs/cbrcore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['cbrcore-1']
# Name: 8, dtype: object
#
# File_Name       configs/cbrcore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['cbrcore-2']
# Name: 9, dtype: object
#
# File_Name          configs/cht-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['cht-gw']
# Name: 10, dtype: object
#
# File_Name       configs/cmtnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['cmtnodegw']
# Name: 11, dtype: object
#
# File_Name          configs/dubagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['dubagg']
# Name: 12, dtype: object
#
# File_Name       configs/dwdnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['dwdnodegw']
# Name: 13, dtype: object
#
# File_Name       configs/dwncore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['dwncore-1']
# Name: 14, dtype: object
#
# File_Name       configs/dwncore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['dwncore-2']
# Name: 15, dtype: object
#
# File_Name       configs/echnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['echnodegw']
# Name: 16, dtype: object
#
# File_Name          configs/edn-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['edn-gw']
# Name: 17, dtype: object
#
# File_Name       configs/engnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['engnodegw']
# Name: 18, dtype: object
#
# File_Name          configs/fre-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['fre-gw']
# Name: 19, dtype: object
#
# File_Name       configs/frknodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['frknodegw']
# Name: 20, dtype: object
#
# File_Name         configs/gdtnagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                     ['gdtnagg']
# Name: 21, dtype: object
#
# File_Name          configs/hobagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['hobagg']
# Name: 22, dtype: object
#
# File_Name       configs/hoenodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['hoenodegw']
# Name: 23, dtype: object
#
# File_Name       configs/hsmnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['hsmnodegw']
# Name: 24, dtype: object
#
# File_Name       configs/infnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['infnodegw']
# Name: 25, dtype: object
#
# File_Name      configs/inkanodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                  ['inkanodegw']
# Name: 26, dtype: object
#
# File_Name          configs/joo-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['joo-gw']
# Name: 27, dtype: object
#
# File_Name       configs/klbnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['klbnodegw']
# Name: 28, dtype: object
#
# File_Name          configs/kng-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['kng-gw']
# Name: 29, dtype: object
#
# File_Name         configs/krthagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                     ['krthagg']
# Name: 30, dtype: object
#
# File_Name          configs/mbr-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['mbr-gw']
# Name: 31, dtype: object
#
# File_Name      configs/meeknodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                  ['meeknodegw']
# Name: 32, dtype: object
#
# File_Name       configs/melcore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['melcore-1']
# Name: 33, dtype: object
#
# File_Name       configs/melcore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['melcore-2']
# Name: 34, dtype: object
#
# File_Name          configs/milagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['milagg']
# Name: 35, dtype: object
#
# File_Name          configs/mkyagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['mkyagg']
# Name: 36, dtype: object
#
# File_Name          configs/mreagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['mreagg']
# Name: 37, dtype: object
#
# File_Name          configs/nkr-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['nkr-gw']
# Name: 38, dtype: object
#
# File_Name       configs/nmnnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['nmnnodegw']
# Name: 39, dtype: object
#
# File_Name       configs/pamnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['pamnodegw']
# Name: 40, dtype: object
#
# File_Name       configs/percore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['percore-1']
# Name: 41, dtype: object
#
# File_Name       configs/percore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['percore-2']
# Name: 42, dtype: object
#
# File_Name          configs/plm-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['plm-gw']
# Name: 43, dtype: object
#
# File_Name          configs/rch-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['rch-gw']
# Name: 44, dtype: object
#
# File_Name          configs/sun-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['sun-gw']
# Name: 45, dtype: object
#
# File_Name       configs/sydcore-1.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['sydcore-1']
# Name: 46, dtype: object
#
# File_Name       configs/sydcore-2.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['sydcore-2']
# Name: 47, dtype: object
#
# File_Name         configs/tncragg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                     ['tncragg']
# Name: 48, dtype: object
#
# File_Name          configs/tor-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['tor-gw']
# Name: 49, dtype: object
#
# File_Name       configs/trinodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['trinodegw']
# Name: 50, dtype: object
#
# File_Name       configs/ungnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['ungnodegw']
# Name: 51, dtype: object
#
# File_Name          configs/wagagg.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['wagagg']
# Name: 52, dtype: object
#
# File_Name       configs/wlwnodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['wlwnodegw']
# Name: 53, dtype: object
#
# File_Name       configs/wwanodegw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                   ['wwanodegw']
# Name: 54, dtype: object
#
# File_Name          configs/yrv-gw.cfg
# Status         PARTIALLY_UNRECOGNIZED
# File_Format      CUMULUS_CONCATENATED
# Nodes                      ['yrv-gw']
# Name: 55, dtype: object
#
# File_Name      hosts/adlcore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['adlcore-1']
# Name: 56, dtype: object
#
# File_Name      hosts/adlcore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['adlcore-2']
# Name: 57, dtype: object
#
# File_Name      hosts/bnecore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['bnecore-1']
# Name: 58, dtype: object
#
# File_Name      hosts/bnecore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['bnecore-2']
# Name: 59, dtype: object
#
# File_Name      hosts/brd-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['brd-gw']
# Name: 60, dtype: object
#
# File_Name      hosts/brwnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['brwnode0']
# Name: 61, dtype: object
#
# File_Name      hosts/brwnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['brwnode1']
# Name: 62, dtype: object
#
# File_Name      hosts/brwnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['brwnodegw']
# Name: 63, dtype: object
#
# File_Name      hosts/byo-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['byo-gw']
# Name: 64, dtype: object
#
# File_Name      hosts/cbpdnode0.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['cbpdnode0']
# Name: 65, dtype: object
#
# File_Name      hosts/cbpdnode1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['cbpdnode1']
# Name: 66, dtype: object
#
# File_Name      hosts/cbpdnodegw.json
# Status                        PASSED
# File_Format                     HOST
# Nodes                 ['cbpdnodegw']
# Name: 67, dtype: object
#
# File_Name      hosts/cbrcore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['cbrcore-1']
# Name: 68, dtype: object
#
# File_Name      hosts/cbrcore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['cbrcore-2']
# Name: 69, dtype: object
#
# File_Name      hosts/cht-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['cht-gw']
# Name: 70, dtype: object
#
# File_Name      hosts/cmtnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['cmtnode0']
# Name: 71, dtype: object
#
# File_Name      hosts/cmtnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['cmtnode1']
# Name: 72, dtype: object
#
# File_Name      hosts/cmtnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['cmtnode2']
# Name: 73, dtype: object
#
# File_Name      hosts/cmtnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['cmtnodegw']
# Name: 74, dtype: object
#
# File_Name      hosts/dubagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['dubagg']
# Name: 75, dtype: object
#
# File_Name      hosts/dubnodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['dubnodec']
# Name: 76, dtype: object
#
# File_Name      hosts/dwdnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['dwdnode0']
# Name: 77, dtype: object
#
# File_Name      hosts/dwdnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['dwdnode1']
# Name: 78, dtype: object
#
# File_Name      hosts/dwdnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['dwdnode2']
# Name: 79, dtype: object
#
# File_Name      hosts/dwdnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['dwdnodegw']
# Name: 80, dtype: object
#
# File_Name      hosts/dwncore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['dwncore-1']
# Name: 81, dtype: object
#
# File_Name      hosts/dwncore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['dwncore-2']
# Name: 82, dtype: object
#
# File_Name      hosts/echnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['echnode0']
# Name: 83, dtype: object
#
# File_Name      hosts/echnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['echnode1']
# Name: 84, dtype: object
#
# File_Name      hosts/echnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['echnode2']
# Name: 85, dtype: object
#
# File_Name      hosts/echnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['echnodegw']
# Name: 86, dtype: object
#
# File_Name      hosts/edn-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['edn-gw']
# Name: 87, dtype: object
#
# File_Name      hosts/eme-brd.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-brd']
# Name: 88, dtype: object
#
# File_Name      hosts/eme-byo.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-byo']
# Name: 89, dtype: object
#
# File_Name      hosts/eme-cht.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-cht']
# Name: 90, dtype: object
#
# File_Name      hosts/eme-edn.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-edn']
# Name: 91, dtype: object
#
# File_Name      hosts/eme-fre.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-fre']
# Name: 92, dtype: object
#
# File_Name      hosts/eme-joo.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-joo']
# Name: 93, dtype: object
#
# File_Name      hosts/eme-kng.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-kng']
# Name: 94, dtype: object
#
# File_Name      hosts/eme-mbr.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-mbr']
# Name: 95, dtype: object
#
# File_Name      hosts/eme-nkr.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-nkr']
# Name: 96, dtype: object
#
# File_Name      hosts/eme-plm.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-plm']
# Name: 97, dtype: object
#
# File_Name      hosts/eme-rch.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-rch']
# Name: 98, dtype: object
#
# File_Name      hosts/eme-sun.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-sun']
# Name: 99, dtype: object
#
# File_Name      hosts/eme-tor.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-tor']
# Name: 100, dtype: object
#
# File_Name      hosts/eme-yrv.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['eme-yrv']
# Name: 101, dtype: object
#
# File_Name      hosts/engnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['engnode0']
# Name: 102, dtype: object
#
# File_Name      hosts/engnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['engnode1']
# Name: 103, dtype: object
#
# File_Name      hosts/engnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['engnode2']
# Name: 104, dtype: object
#
# File_Name      hosts/engnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['engnodegw']
# Name: 105, dtype: object
#
# File_Name      hosts/ess-brd.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-brd']
# Name: 106, dtype: object
#
# File_Name      hosts/ess-byo.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-byo']
# Name: 107, dtype: object
#
# File_Name      hosts/ess-cht.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-cht']
# Name: 108, dtype: object
#
# File_Name      hosts/ess-edn.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-edn']
# Name: 109, dtype: object
#
# File_Name      hosts/ess-fre.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-fre']
# Name: 110, dtype: object
#
# File_Name      hosts/ess-joo.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-joo']
# Name: 111, dtype: object
#
# File_Name      hosts/ess-kng.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-kng']
# Name: 112, dtype: object
#
# File_Name      hosts/ess-mbr.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-mbr']
# Name: 113, dtype: object
#
# File_Name      hosts/ess-nkr.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-nkr']
# Name: 114, dtype: object
#
# File_Name      hosts/ess-plm.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-plm']
# Name: 115, dtype: object
#
# File_Name      hosts/ess-rch.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-rch']
# Name: 116, dtype: object
#
# File_Name      hosts/ess-sun.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-sun']
# Name: 117, dtype: object
#
# File_Name      hosts/ess-tor.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-tor']
# Name: 118, dtype: object
#
# File_Name      hosts/ess-yrv.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['ess-yrv']
# Name: 119, dtype: object
#
# File_Name      hosts/fre-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['fre-gw']
# Name: 120, dtype: object
#
# File_Name      hosts/frknode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['frknode0']
# Name: 121, dtype: object
#
# File_Name      hosts/frknode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['frknode1']
# Name: 122, dtype: object
#
# File_Name      hosts/frknode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['frknode2']
# Name: 123, dtype: object
#
# File_Name      hosts/frknodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['frknodegw']
# Name: 124, dtype: object
#
# File_Name      hosts/gdtnagg.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['gdtnagg']
# Name: 125, dtype: object
#
# File_Name      hosts/gdtnnodec.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['gdtnnodec']
# Name: 126, dtype: object
#
# File_Name      hosts/hobagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['hobagg']
# Name: 127, dtype: object
#
# File_Name      hosts/hobnodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['hobnodec']
# Name: 128, dtype: object
#
# File_Name      hosts/hoenode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['hoenode0']
# Name: 129, dtype: object
#
# File_Name      hosts/hoenode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['hoenode1']
# Name: 130, dtype: object
#
# File_Name      hosts/hoenodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['hoenodegw']
# Name: 131, dtype: object
#
# File_Name      hosts/hsmnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['hsmnode0']
# Name: 132, dtype: object
#
# File_Name      hosts/hsmnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['hsmnode1']
# Name: 133, dtype: object
#
# File_Name      hosts/hsmnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['hsmnodegw']
# Name: 134, dtype: object
#
# File_Name      hosts/infnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['infnode0']
# Name: 135, dtype: object
#
# File_Name      hosts/infnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['infnode1']
# Name: 136, dtype: object
#
# File_Name      hosts/infnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['infnodegw']
# Name: 137, dtype: object
#
# File_Name      hosts/inkanode0.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['inkanode0']
# Name: 138, dtype: object
#
# File_Name      hosts/inkanode1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['inkanode1']
# Name: 139, dtype: object
#
# File_Name      hosts/inkanode2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['inkanode2']
# Name: 140, dtype: object
#
# File_Name      hosts/inkanodegw.json
# Status                        PASSED
# File_Format                     HOST
# Nodes                 ['inkanodegw']
# Name: 141, dtype: object
#
# File_Name      hosts/joo-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['joo-gw']
# Name: 142, dtype: object
#
# File_Name      hosts/klbnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['klbnode0']
# Name: 143, dtype: object
#
# File_Name      hosts/klbnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['klbnode1']
# Name: 144, dtype: object
#
# File_Name      hosts/klbnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['klbnodegw']
# Name: 145, dtype: object
#
# File_Name      hosts/kng-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['kng-gw']
# Name: 146, dtype: object
#
# File_Name      hosts/krthagg.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['krthagg']
# Name: 147, dtype: object
#
# File_Name      hosts/krthnodec.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['krthnodec']
# Name: 148, dtype: object
#
# File_Name      hosts/mbr-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['mbr-gw']
# Name: 149, dtype: object
#
# File_Name      hosts/meeknode0.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['meeknode0']
# Name: 150, dtype: object
#
# File_Name      hosts/meeknode1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['meeknode1']
# Name: 151, dtype: object
#
# File_Name      hosts/meeknode2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['meeknode2']
# Name: 152, dtype: object
#
# File_Name      hosts/meeknodegw.json
# Status                        PASSED
# File_Format                     HOST
# Nodes                 ['meeknodegw']
# Name: 153, dtype: object
#
# File_Name      hosts/melcore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['melcore-1']
# Name: 154, dtype: object
#
# File_Name      hosts/melcore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['melcore-2']
# Name: 155, dtype: object
#
# File_Name      hosts/milagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['milagg']
# Name: 156, dtype: object
#
# File_Name      hosts/milnodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['milnodec']
# Name: 157, dtype: object
#
# File_Name      hosts/mkyagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['mkyagg']
# Name: 158, dtype: object
#
# File_Name      hosts/mkynodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['mkynodec']
# Name: 159, dtype: object
#
# File_Name      hosts/mreagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['mreagg']
# Name: 160, dtype: object
#
# File_Name      hosts/mrenodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['mrenodec']
# Name: 161, dtype: object
#
# File_Name      hosts/nkr-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['nkr-gw']
# Name: 162, dtype: object
#
# File_Name      hosts/nmnnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['nmnnode0']
# Name: 163, dtype: object
#
# File_Name      hosts/nmnnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['nmnnode1']
# Name: 164, dtype: object
#
# File_Name      hosts/nmnnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['nmnnode2']
# Name: 165, dtype: object
#
# File_Name      hosts/nmnnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['nmnnodegw']
# Name: 166, dtype: object
#
# File_Name      hosts/pamnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['pamnode0']
# Name: 167, dtype: object
#
# File_Name      hosts/pamnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['pamnode1']
# Name: 168, dtype: object
#
# File_Name      hosts/pamnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['pamnode2']
# Name: 169, dtype: object
#
# File_Name      hosts/pamnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['pamnodegw']
# Name: 170, dtype: object
#
# File_Name      hosts/percore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['percore-1']
# Name: 171, dtype: object
#
# File_Name      hosts/percore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['percore-2']
# Name: 172, dtype: object
#
# File_Name      hosts/plm-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['plm-gw']
# Name: 173, dtype: object
#
# File_Name      hosts/rch-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['rch-gw']
# Name: 174, dtype: object
#
# File_Name      hosts/sun-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['sun-gw']
# Name: 175, dtype: object
#
# File_Name      hosts/sydcore-1.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['sydcore-1']
# Name: 176, dtype: object
#
# File_Name      hosts/sydcore-2.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['sydcore-2']
# Name: 177, dtype: object
#
# File_Name      hosts/tncragg.json
# Status                     PASSED
# File_Format                  HOST
# Nodes                 ['tncragg']
# Name: 178, dtype: object
#
# File_Name      hosts/tncrnodec.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['tncrnodec']
# Name: 179, dtype: object
#
# File_Name      hosts/tor-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['tor-gw']
# Name: 180, dtype: object
#
# File_Name      hosts/trinode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['trinode0']
# Name: 181, dtype: object
#
# File_Name      hosts/trinode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['trinode1']
# Name: 182, dtype: object
#
# File_Name      hosts/trinode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['trinode2']
# Name: 183, dtype: object
#
# File_Name      hosts/trinodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['trinodegw']
# Name: 184, dtype: object
#
# File_Name      hosts/ungnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['ungnode0']
# Name: 185, dtype: object
#
# File_Name      hosts/ungnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['ungnode1']
# Name: 186, dtype: object
#
# File_Name      hosts/ungnode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['ungnode2']
# Name: 187, dtype: object
#
# File_Name      hosts/ungnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['ungnodegw']
# Name: 188, dtype: object
#
# File_Name      hosts/wagagg.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['wagagg']
# Name: 189, dtype: object
#
# File_Name      hosts/wagnodec.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wagnodec']
# Name: 190, dtype: object
#
# File_Name      hosts/wlwnode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wlwnode0']
# Name: 191, dtype: object
#
# File_Name      hosts/wlwnode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wlwnode1']
# Name: 192, dtype: object
#
# File_Name      hosts/wlwnodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['wlwnodegw']
# Name: 193, dtype: object
#
# File_Name      hosts/wwanode0.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wwanode0']
# Name: 194, dtype: object
#
# File_Name      hosts/wwanode1.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wwanode1']
# Name: 195, dtype: object
#
# File_Name      hosts/wwanode2.json
# Status                      PASSED
# File_Format                   HOST
# Nodes                 ['wwanode2']
# Name: 196, dtype: object
#
# File_Name      hosts/wwanodegw.json
# Status                       PASSED
# File_Format                    HOST
# Nodes                 ['wwanodegw']
# Name: 197, dtype: object
#
# File_Name      hosts/yrv-gw.json
# Status                    PASSED
# File_Format                 HOST
# Nodes                 ['yrv-gw']
# Name: 198, dtype: object
#
# File_Name          iptables/adlcore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/adlcore-1.iptables']
# Name: 199, dtype: object
#
# File_Name          iptables/adlcore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/adlcore-2.iptables']
# Name: 200, dtype: object
#
# File_Name          iptables/bnecore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/bnecore-1.iptables']
# Name: 201, dtype: object
#
# File_Name          iptables/bnecore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/bnecore-2.iptables']
# Name: 202, dtype: object
#
# File_Name          iptables/brd-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/brd-gw.iptables']
# Name: 203, dtype: object
#
# File_Name          iptables/brwnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/brwnode0.iptables']
# Name: 204, dtype: object
#
# File_Name          iptables/brwnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/brwnode1.iptables']
# Name: 205, dtype: object
#
# File_Name          iptables/brwnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/brwnodegw.iptables']
# Name: 206, dtype: object
#
# File_Name          iptables/byo-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/byo-gw.iptables']
# Name: 207, dtype: object
#
# File_Name          iptables/cbpdnode0.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/cbpdnode0.iptables']
# Name: 208, dtype: object
#
# File_Name          iptables/cbpdnode1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/cbpdnode1.iptables']
# Name: 209, dtype: object
#
# File_Name          iptables/cbpdnodegw.iptables
# Status                                   PASSED
# File_Format                            IPTABLES
# Nodes          ['iptables/cbpdnodegw.iptables']
# Name: 210, dtype: object
#
# File_Name          iptables/cbrcore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/cbrcore-1.iptables']
# Name: 211, dtype: object
#
# File_Name          iptables/cbrcore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/cbrcore-2.iptables']
# Name: 212, dtype: object
#
# File_Name          iptables/cht-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/cht-gw.iptables']
# Name: 213, dtype: object
#
# File_Name          iptables/cmtnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/cmtnode0.iptables']
# Name: 214, dtype: object
#
# File_Name          iptables/cmtnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/cmtnode1.iptables']
# Name: 215, dtype: object
#
# File_Name          iptables/cmtnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/cmtnode2.iptables']
# Name: 216, dtype: object
#
# File_Name          iptables/cmtnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/cmtnodegw.iptables']
# Name: 217, dtype: object
#
# File_Name          iptables/dubagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/dubagg.iptables']
# Name: 218, dtype: object
#
# File_Name          iptables/dubnodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/dubnodec.iptables']
# Name: 219, dtype: object
#
# File_Name          iptables/dwdnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/dwdnode0.iptables']
# Name: 220, dtype: object
#
# File_Name          iptables/dwdnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/dwdnode1.iptables']
# Name: 221, dtype: object
#
# File_Name          iptables/dwdnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/dwdnode2.iptables']
# Name: 222, dtype: object
#
# File_Name          iptables/dwdnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/dwdnodegw.iptables']
# Name: 223, dtype: object
#
# File_Name          iptables/dwncore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/dwncore-1.iptables']
# Name: 224, dtype: object
#
# File_Name          iptables/dwncore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/dwncore-2.iptables']
# Name: 225, dtype: object
#
# File_Name          iptables/echnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/echnode0.iptables']
# Name: 226, dtype: object
#
# File_Name          iptables/echnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/echnode1.iptables']
# Name: 227, dtype: object
#
# File_Name          iptables/echnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/echnode2.iptables']
# Name: 228, dtype: object
#
# File_Name          iptables/echnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/echnodegw.iptables']
# Name: 229, dtype: object
#
# File_Name          iptables/edn-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/edn-gw.iptables']
# Name: 230, dtype: object
#
# File_Name          iptables/eme-brd.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-brd.iptables']
# Name: 231, dtype: object
#
# File_Name          iptables/eme-byo.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-byo.iptables']
# Name: 232, dtype: object
#
# File_Name          iptables/eme-cht.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-cht.iptables']
# Name: 233, dtype: object
#
# File_Name          iptables/eme-edn.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-edn.iptables']
# Name: 234, dtype: object
#
# File_Name          iptables/eme-fre.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-fre.iptables']
# Name: 235, dtype: object
#
# File_Name          iptables/eme-joo.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-joo.iptables']
# Name: 236, dtype: object
#
# File_Name          iptables/eme-kng.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-kng.iptables']
# Name: 237, dtype: object
#
# File_Name          iptables/eme-mbr.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-mbr.iptables']
# Name: 238, dtype: object
#
# File_Name          iptables/eme-nkr.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-nkr.iptables']
# Name: 239, dtype: object
#
# File_Name          iptables/eme-plm.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-plm.iptables']
# Name: 240, dtype: object
#
# File_Name          iptables/eme-rch.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-rch.iptables']
# Name: 241, dtype: object
#
# File_Name          iptables/eme-sun.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-sun.iptables']
# Name: 242, dtype: object
#
# File_Name          iptables/eme-tor.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-tor.iptables']
# Name: 243, dtype: object
#
# File_Name          iptables/eme-yrv.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/eme-yrv.iptables']
# Name: 244, dtype: object
#
# File_Name          iptables/engnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/engnode0.iptables']
# Name: 245, dtype: object
#
# File_Name          iptables/engnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/engnode1.iptables']
# Name: 246, dtype: object
#
# File_Name          iptables/engnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/engnode2.iptables']
# Name: 247, dtype: object
#
# File_Name          iptables/engnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/engnodegw.iptables']
# Name: 248, dtype: object
#
# File_Name          iptables/ess-brd.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-brd.iptables']
# Name: 249, dtype: object
#
# File_Name          iptables/ess-byo.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-byo.iptables']
# Name: 250, dtype: object
#
# File_Name          iptables/ess-cht.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-cht.iptables']
# Name: 251, dtype: object
#
# File_Name          iptables/ess-edn.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-edn.iptables']
# Name: 252, dtype: object
#
# File_Name          iptables/ess-fre.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-fre.iptables']
# Name: 253, dtype: object
#
# File_Name          iptables/ess-joo.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-joo.iptables']
# Name: 254, dtype: object
#
# File_Name          iptables/ess-kng.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-kng.iptables']
# Name: 255, dtype: object
#
# File_Name          iptables/ess-mbr.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-mbr.iptables']
# Name: 256, dtype: object
#
# File_Name          iptables/ess-nkr.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-nkr.iptables']
# Name: 257, dtype: object
#
# File_Name          iptables/ess-plm.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-plm.iptables']
# Name: 258, dtype: object
#
# File_Name          iptables/ess-rch.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-rch.iptables']
# Name: 259, dtype: object
#
# File_Name          iptables/ess-sun.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-sun.iptables']
# Name: 260, dtype: object
#
# File_Name          iptables/ess-tor.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-tor.iptables']
# Name: 261, dtype: object
#
# File_Name          iptables/ess-yrv.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/ess-yrv.iptables']
# Name: 262, dtype: object
#
# File_Name          iptables/fre-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/fre-gw.iptables']
# Name: 263, dtype: object
#
# File_Name          iptables/frknode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/frknode0.iptables']
# Name: 264, dtype: object
#
# File_Name          iptables/frknode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/frknode1.iptables']
# Name: 265, dtype: object
#
# File_Name          iptables/frknode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/frknode2.iptables']
# Name: 266, dtype: object
#
# File_Name          iptables/frknodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/frknodegw.iptables']
# Name: 267, dtype: object
#
# File_Name          iptables/gdtnagg.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/gdtnagg.iptables']
# Name: 268, dtype: object
#
# File_Name          iptables/gdtnnodec.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/gdtnnodec.iptables']
# Name: 269, dtype: object
#
# File_Name          iptables/hobagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/hobagg.iptables']
# Name: 270, dtype: object
#
# File_Name          iptables/hobnodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/hobnodec.iptables']
# Name: 271, dtype: object
#
# File_Name          iptables/hoenode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/hoenode0.iptables']
# Name: 272, dtype: object
#
# File_Name          iptables/hoenode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/hoenode1.iptables']
# Name: 273, dtype: object
#
# File_Name          iptables/hoenodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/hoenodegw.iptables']
# Name: 274, dtype: object
#
# File_Name          iptables/hsmnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/hsmnode0.iptables']
# Name: 275, dtype: object
#
# File_Name          iptables/hsmnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/hsmnode1.iptables']
# Name: 276, dtype: object
#
# File_Name          iptables/hsmnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/hsmnodegw.iptables']
# Name: 277, dtype: object
#
# File_Name          iptables/infnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/infnode0.iptables']
# Name: 278, dtype: object
#
# File_Name          iptables/infnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/infnode1.iptables']
# Name: 279, dtype: object
#
# File_Name          iptables/infnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/infnodegw.iptables']
# Name: 280, dtype: object
#
# File_Name          iptables/inkanode0.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/inkanode0.iptables']
# Name: 281, dtype: object
#
# File_Name          iptables/inkanode1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/inkanode1.iptables']
# Name: 282, dtype: object
#
# File_Name          iptables/inkanode2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/inkanode2.iptables']
# Name: 283, dtype: object
#
# File_Name          iptables/inkanodegw.iptables
# Status                                   PASSED
# File_Format                            IPTABLES
# Nodes          ['iptables/inkanodegw.iptables']
# Name: 284, dtype: object
#
# File_Name          iptables/joo-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/joo-gw.iptables']
# Name: 285, dtype: object
#
# File_Name          iptables/klbnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/klbnode0.iptables']
# Name: 286, dtype: object
#
# File_Name          iptables/klbnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/klbnode1.iptables']
# Name: 287, dtype: object
#
# File_Name          iptables/klbnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/klbnodegw.iptables']
# Name: 288, dtype: object
#
# File_Name          iptables/kng-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/kng-gw.iptables']
# Name: 289, dtype: object
#
# File_Name          iptables/krthagg.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/krthagg.iptables']
# Name: 290, dtype: object
#
# File_Name          iptables/krthnodec.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/krthnodec.iptables']
# Name: 291, dtype: object
#
# File_Name          iptables/mbr-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/mbr-gw.iptables']
# Name: 292, dtype: object
#
# File_Name          iptables/meeknode0.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/meeknode0.iptables']
# Name: 293, dtype: object
#
# File_Name          iptables/meeknode1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/meeknode1.iptables']
# Name: 294, dtype: object
#
# File_Name          iptables/meeknode2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/meeknode2.iptables']
# Name: 295, dtype: object
#
# File_Name          iptables/meeknodegw.iptables
# Status                                   PASSED
# File_Format                            IPTABLES
# Nodes          ['iptables/meeknodegw.iptables']
# Name: 296, dtype: object
#
# File_Name          iptables/melcore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/melcore-1.iptables']
# Name: 297, dtype: object
#
# File_Name          iptables/melcore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/melcore-2.iptables']
# Name: 298, dtype: object
#
# File_Name          iptables/milagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/milagg.iptables']
# Name: 299, dtype: object
#
# File_Name          iptables/milnodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/milnodec.iptables']
# Name: 300, dtype: object
#
# File_Name          iptables/mkyagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/mkyagg.iptables']
# Name: 301, dtype: object
#
# File_Name          iptables/mkynodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/mkynodec.iptables']
# Name: 302, dtype: object
#
# File_Name          iptables/mreagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/mreagg.iptables']
# Name: 303, dtype: object
#
# File_Name          iptables/mrenodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/mrenodec.iptables']
# Name: 304, dtype: object
#
# File_Name          iptables/nkr-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/nkr-gw.iptables']
# Name: 305, dtype: object
#
# File_Name          iptables/nmnnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/nmnnode0.iptables']
# Name: 306, dtype: object
#
# File_Name          iptables/nmnnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/nmnnode1.iptables']
# Name: 307, dtype: object
#
# File_Name          iptables/nmnnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/nmnnode2.iptables']
# Name: 308, dtype: object
#
# File_Name          iptables/nmnnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/nmnnodegw.iptables']
# Name: 309, dtype: object
#
# File_Name          iptables/pamnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/pamnode0.iptables']
# Name: 310, dtype: object
#
# File_Name          iptables/pamnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/pamnode1.iptables']
# Name: 311, dtype: object
#
# File_Name          iptables/pamnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/pamnode2.iptables']
# Name: 312, dtype: object
#
# File_Name          iptables/pamnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/pamnodegw.iptables']
# Name: 313, dtype: object
#
# File_Name          iptables/percore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/percore-1.iptables']
# Name: 314, dtype: object
#
# File_Name          iptables/percore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/percore-2.iptables']
# Name: 315, dtype: object
#
# File_Name          iptables/plm-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/plm-gw.iptables']
# Name: 316, dtype: object
#
# File_Name          iptables/rch-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/rch-gw.iptables']
# Name: 317, dtype: object
#
# File_Name          iptables/sun-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/sun-gw.iptables']
# Name: 318, dtype: object
#
# File_Name          iptables/sydcore-1.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/sydcore-1.iptables']
# Name: 319, dtype: object
#
# File_Name          iptables/sydcore-2.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/sydcore-2.iptables']
# Name: 320, dtype: object
#
# File_Name          iptables/tncragg.iptables
# Status                                PASSED
# File_Format                         IPTABLES
# Nodes          ['iptables/tncragg.iptables']
# Name: 321, dtype: object
#
# File_Name          iptables/tncrnodec.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/tncrnodec.iptables']
# Name: 322, dtype: object
#
# File_Name          iptables/tor-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/tor-gw.iptables']
# Name: 323, dtype: object
#
# File_Name          iptables/trinode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/trinode0.iptables']
# Name: 324, dtype: object
#
# File_Name          iptables/trinode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/trinode1.iptables']
# Name: 325, dtype: object
#
# File_Name          iptables/trinode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/trinode2.iptables']
# Name: 326, dtype: object
#
# File_Name          iptables/trinodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/trinodegw.iptables']
# Name: 327, dtype: object
#
# File_Name          iptables/ungnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/ungnode0.iptables']
# Name: 328, dtype: object
#
# File_Name          iptables/ungnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/ungnode1.iptables']
# Name: 329, dtype: object
#
# File_Name          iptables/ungnode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/ungnode2.iptables']
# Name: 330, dtype: object
#
# File_Name          iptables/ungnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/ungnodegw.iptables']
# Name: 331, dtype: object
#
# File_Name          iptables/wagagg.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/wagagg.iptables']
# Name: 332, dtype: object
#
# File_Name          iptables/wagnodec.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wagnodec.iptables']
# Name: 333, dtype: object
#
# File_Name          iptables/wlwnode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wlwnode0.iptables']
# Name: 334, dtype: object
#
# File_Name          iptables/wlwnode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wlwnode1.iptables']
# Name: 335, dtype: object
#
# File_Name          iptables/wlwnodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/wlwnodegw.iptables']
# Name: 336, dtype: object
#
# File_Name          iptables/wwanode0.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wwanode0.iptables']
# Name: 337, dtype: object
#
# File_Name          iptables/wwanode1.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wwanode1.iptables']
# Name: 338, dtype: object
#
# File_Name          iptables/wwanode2.iptables
# Status                                 PASSED
# File_Format                          IPTABLES
# Nodes          ['iptables/wwanode2.iptables']
# Name: 339, dtype: object
#
# File_Name          iptables/wwanodegw.iptables
# Status                                  PASSED
# File_Format                           IPTABLES
# Nodes          ['iptables/wwanodegw.iptables']
# Name: 340, dtype: object
#
# File_Name          iptables/yrv-gw.iptables
# Status                               PASSED
# File_Format                        IPTABLES
# Nodes          ['iptables/yrv-gw.iptables']
# Name: 341, dtype: object

# %%
# An example: use a filter on the returned dataframe to see which files failed to parse completely
parse_status[parse_status['Status'] != 'PASSED']  # change '!=' to '==' to get the files which passed
# Out:
#                  File_Name                  Status           File_Format  \
# 0    configs/adlcore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 1    configs/adlcore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 2    configs/bnecore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 3    configs/bnecore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 4       configs/brd-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 5    configs/brwnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 6       configs/byo-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 7   configs/cbpdnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 8    configs/cbrcore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 9    configs/cbrcore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 10      configs/cht-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 11   configs/cmtnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 12      configs/dubagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 13   configs/dwdnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 14   configs/dwncore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 15   configs/dwncore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 16   configs/echnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 17      configs/edn-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 18   configs/engnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 19      configs/fre-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 20   configs/frknodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 21     configs/gdtnagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 22      configs/hobagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 23   configs/hoenodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 24   configs/hsmnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 25   configs/infnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 26  configs/inkanodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 27      configs/joo-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 28   configs/klbnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 29      configs/kng-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 30     configs/krthagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 31      configs/mbr-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 32  configs/meeknodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 33   configs/melcore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 34   configs/melcore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 35      configs/milagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 36      configs/mkyagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 37      configs/mreagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 38      configs/nkr-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 39   configs/nmnnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 40   configs/pamnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 41   configs/percore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 42   configs/percore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 43      configs/plm-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 44      configs/rch-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 45      configs/sun-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 46   configs/sydcore-1.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 47   configs/sydcore-2.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 48     configs/tncragg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 49      configs/tor-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 50   configs/trinodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 51   configs/ungnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 52      configs/wagagg.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 53   configs/wlwnodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 54   configs/wwanodegw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
# 55      configs/yrv-gw.cfg  PARTIALLY_UNRECOGNIZED  CUMULUS_CONCATENATED
#
#              Nodes
# 0    ['adlcore-1']
# 1    ['adlcore-2']
# 2    ['bnecore-1']
# 3    ['bnecore-2']
# 4       ['brd-gw']
# 5    ['brwnodegw']
# 6       ['byo-gw']
# 7   ['cbpdnodegw']
# 8    ['cbrcore-1']
# 9    ['cbrcore-2']
# 10      ['cht-gw']
# 11   ['cmtnodegw']
# 12      ['dubagg']
# 13   ['dwdnodegw']
# 14   ['dwncore-1']
# 15   ['dwncore-2']
# 16   ['echnodegw']
# 17      ['edn-gw']
# 18   ['engnodegw']
# 19      ['fre-gw']
# 20   ['frknodegw']
# 21     ['gdtnagg']
# 22      ['hobagg']
# 23   ['hoenodegw']
# 24   ['hsmnodegw']
# 25   ['infnodegw']
# 26  ['inkanodegw']
# 27      ['joo-gw']
# 28   ['klbnodegw']
# 29      ['kng-gw']
# 30     ['krthagg']
# 31      ['mbr-gw']
# 32  ['meeknodegw']
# 33   ['melcore-1']
# 34   ['melcore-2']
# 35      ['milagg']
# 36      ['mkyagg']
# 37      ['mreagg']
# 38      ['nkr-gw']
# 39   ['nmnnodegw']
# 40   ['pamnodegw']
# 41   ['percore-1']
# 42   ['percore-2']
# 43      ['plm-gw']
# 44      ['rch-gw']
# 45      ['sun-gw']
# 46   ['sydcore-1']
# 47   ['sydcore-2']
# 48     ['tncragg']
# 49      ['tor-gw']
# 50   ['trinodegw']
# 51   ['ungnodegw']
# 52      ['wagagg']
# 53   ['wlwnodegw']
# 54   ['wwanodegw']
# 55      ['yrv-gw']

# %%
# An example: use a filter on the returned dataframe to see which files parse completely
parse_status[parse_status['Status'] == 'PASSED']  # change '!=' to '==' to get the files which passed
# Out:
#                        File_Name  Status File_Format  \
# 56          hosts/adlcore-1.json  PASSED        HOST
# 57          hosts/adlcore-2.json  PASSED        HOST
# 58          hosts/bnecore-1.json  PASSED        HOST
# 59          hosts/bnecore-2.json  PASSED        HOST
# 60             hosts/brd-gw.json  PASSED        HOST
# ..                           ...     ...         ...
# 337   iptables/wwanode0.iptables  PASSED    IPTABLES
# 338   iptables/wwanode1.iptables  PASSED    IPTABLES
# 339   iptables/wwanode2.iptables  PASSED    IPTABLES
# 340  iptables/wwanodegw.iptables  PASSED    IPTABLES
# 341     iptables/yrv-gw.iptables  PASSED    IPTABLES
#
#                                Nodes
# 56                     ['adlcore-1']
# 57                     ['adlcore-2']
# 58                     ['bnecore-1']
# 59                     ['bnecore-2']
# 60                        ['brd-gw']
# ..                               ...
# 337   ['iptables/wwanode0.iptables']
# 338   ['iptables/wwanode1.iptables']
# 339   ['iptables/wwanode2.iptables']
# 340  ['iptables/wwanodegw.iptables']
# 341     ['iptables/yrv-gw.iptables']
#
# [286 rows x 4 columns]

# %%
# View details if some of the files were not parsed completely
for i in range(220, 240):
    print(bf.q.parseWarning().answer().frame().iloc[i])
    print(' ')
# Out:
# Filename                                              configs/cmtnodegw.cfg
# Line                                                                     57
# Text                                                ip ospf dead-interval 6
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 220, dtype: object
#
# Filename                                              configs/cmtnodegw.cfg
# Line                                                                     58
# Text                                               ip ospf hello-interval 2
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 221, dtype: object
#
# Filename                              configs/cmtnodegw.cfg
# Line                                                     60
# Text                                                   exit
# Parser_Context    [s_interface statement frr_configuration]
# Comment                         This syntax is unrecognized
# Name: 222, dtype: object
#
# Filename                                configs/cmtnodegw.cfg
# Line                                                       68
# Text                                        capability opaque
# Parser_Context    [s_router_ospf statement frr_configuration]
# Comment                           This syntax is unrecognized
# Name: 223, dtype: object
#
# Filename                                configs/cmtnodegw.cfg
# Line                                                       69
# Text                                                     exit
# Parser_Context    [s_router_ospf statement frr_configuration]
# Comment                           This syntax is unrecognized
# Name: 224, dtype: object
#
# Filename                   configs/dubagg.cfg
# Line                                       34
# Text                Building configuration...
# Parser_Context            [frr_configuration]
# Comment           This syntax is unrecognized
# Name: 225, dtype: object
#
# Filename                   configs/dubagg.cfg
# Line                                       36
# Text                   Current configuration:
# Parser_Context            [frr_configuration]
# Comment           This syntax is unrecognized
# Name: 226, dtype: object
#
# Filename                          configs/dubagg.cfg
# Line                                              44
# Text                      ip router-id 10.20.154.229
# Parser_Context    [s_ip statement frr_configuration]
# Comment                  This syntax is unrecognized
# Name: 227, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     47
# Text                                                ip ospf dead-interval 6
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 228, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     48
# Text                                               ip ospf hello-interval 2
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 229, dtype: object
#
# Filename                                 configs/dubagg.cfg
# Line                                                     50
# Text                                                   exit
# Parser_Context    [s_interface statement frr_configuration]
# Comment                         This syntax is unrecognized
# Name: 230, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     53
# Text                                                ip ospf dead-interval 6
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 231, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     54
# Text                                               ip ospf hello-interval 2
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 232, dtype: object
#
# Filename                                 configs/dubagg.cfg
# Line                                                     56
# Text                                                   exit
# Parser_Context    [s_interface statement frr_configuration]
# Comment                         This syntax is unrecognized
# Name: 233, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     59
# Text                                                ip ospf dead-interval 6
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 234, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     60
# Text                                               ip ospf hello-interval 2
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 235, dtype: object
#
# Filename                                 configs/dubagg.cfg
# Line                                                     62
# Text                                                   exit
# Parser_Context    [s_interface statement frr_configuration]
# Comment                         This syntax is unrecognized
# Name: 236, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     65
# Text                                                ip ospf dead-interval 6
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 237, dtype: object
#
# Filename                                                 configs/dubagg.cfg
# Line                                                                     66
# Text                                               ip ospf hello-interval 2
# Parser_Context    [siip_ospf si_ip s_interface statement frr_configuration]
# Comment                                         This syntax is unrecognized
# Name: 238, dtype: object
#
# Filename                                 configs/dubagg.cfg
# Line                                                     68
# Text                                                   exit
# Parser_Context    [s_interface statement frr_configuration]
# Comment                         This syntax is unrecognized
# Name: 239, dtype: object

# %%
interface_properties = bf.q.interfaceProperties().answer().frame()

# %%
interface_properties
# Out:
#            Interface Access_VLAN Active Admin_Up          All_Prefixes  \
# 0    adlcore-1[eth0]        None   True     True    ['10.21.9.193/30']
# 1    adlcore-1[eth1]        None   True     True   ['10.22.27.115/29']
# 2    adlcore-1[eth2]        None   True     True    ['10.22.11.73/29']
# 3    adlcore-1[eth3]        None   True     True    ['10.10.22.25/30']
# 4    adlcore-1[eth4]        None   True     True   ['10.10.10.198/30']
# ..               ...         ...    ...      ...                   ...
# 401    wwanodegw[lo]        None   True     True       ['127.0.0.1/8']
# 402     yrv-gw[eth0]        None   True     True  ['10.22.217.196/29']
# 403     yrv-gw[eth1]        None   True     True  ['10.22.221.181/29']
# 404     yrv-gw[eth2]        None   True     True  ['10.23.208.165/29']
# 405       yrv-gw[lo]        None   True     True       ['127.0.0.1/8']
#
#     Allowed_VLANs Auto_State_VLAN      Bandwidth Blacklisted Channel_Group  \
# 0                            True  10000000000.0       False          None
# 1                            True  10000000000.0       False          None
# 2                            True  10000000000.0       False          None
# 3                            True  10000000000.0       False          None
# 4                            True  10000000000.0       False          None
# ..            ...             ...            ...         ...           ...
# 401                          True   8000000000.0        None          None
# 402                          True  10000000000.0       False          None
# 403                          True  10000000000.0       False          None
# 404                          True  10000000000.0       False          None
# 405                          True   8000000000.0        None          None
#
#     Channel_Group_Members DHCP_Relay_Addresses Declared_Names Description  \
# 0                      []                   []             []        None
# 1                      []                   []             []        None
# 2                      []                   []             []        None
# 3                      []                   []             []        None
# 4                      []                   []             []        None
# ..                    ...                  ...            ...         ...
# 401                    []                   []             []        None
# 402                    []                   []             []        None
# 403                    []                   []             []        None
# 404                    []                   []             []        None
# 405                    []                   []             []        None
#
#     Encapsulation_VLAN HSRP_Groups HSRP_Version Inactive_Reason  \
# 0                 None          []         None
# 1                 None          []         None
# 2                 None          []         None
# 3                 None          []         None
# 4                 None          []         None
# ..                 ...         ...          ...             ...
# 401               None          []         None
# 402               None          []         None
# 403               None          []         None
# 404               None          []         None
# 405               None          []         None
#
#     Incoming_Filter_Name MLAG_ID    MTU Native_VLAN Outgoing_Filter_Name  \
# 0                   None    None   1500        None      filter::FORWARD
# 1                   None    None   1500        None      filter::FORWARD
# 2                   None    None   1500        None      filter::FORWARD
# 3                   None    None   1500        None      filter::FORWARD
# 4                   None    None   1500        None      filter::FORWARD
# ..                   ...     ...    ...         ...                  ...
# 401                 None    None  65536        None      filter::FORWARD
# 402                 None    None   1500        None      filter::FORWARD
# 403                 None    None   1500        None      filter::FORWARD
# 404                 None    None   1500        None      filter::FORWARD
# 405                 None    None  65536        None      filter::FORWARD
#
#     PBR_Policy_Name   Primary_Address   Primary_Network Proxy_ARP Rip_Enabled  \
# 0              None    10.21.9.193/30    10.21.9.192/30     False       False
# 1              None   10.22.27.115/29   10.22.27.112/29     False       False
# 2              None    10.22.11.73/29    10.22.11.72/29     False       False
# 3              None    10.10.22.25/30    10.10.22.24/30     False       False
# 4              None   10.10.10.198/30   10.10.10.196/30     False       False
# ..              ...               ...               ...       ...         ...
# 401            None       127.0.0.1/8       127.0.0.0/8     False       False
# 402            None  10.22.217.196/29  10.22.217.192/29     False       False
# 403            None  10.22.221.181/29  10.22.221.176/29     False       False
# 404            None  10.23.208.165/29  10.23.208.160/29     False       False
# 405            None       127.0.0.1/8       127.0.0.0/8     False       False
#
#     Rip_Passive Spanning_Tree_Portfast Speed Switchport Switchport_Mode  \
# 0         False                  False  None      False            NONE
# 1         False                  False  None      False            NONE
# 2         False                  False  None      False            NONE
# 3         False                  False  None      False            NONE
# 4         False                  False  None      False            NONE
# ..          ...                    ...   ...        ...             ...
# 401       False                  False  None      False            NONE
# 402       False                  False  None      False            NONE
# 403       False                  False  None      False            NONE
# 404       False                  False  None      False            NONE
# 405       False                  False  None      False            NONE
#
#     Switchport_Trunk_Encapsulation      VRF VRRP_Groups Zone_Name
# 0                            DOT1Q  default          []      None
# 1                            DOT1Q  default          []      None
# 2                            DOT1Q  default          []      None
# 3                            DOT1Q  default          []      None
# 4                            DOT1Q  default          []      None
# ..                             ...      ...         ...       ...
# 401                          DOT1Q  default          []      None
# 402                          DOT1Q  default          []      None
# 403                          DOT1Q  default          []      None
# 404                          DOT1Q  default          []      None
# 405                          DOT1Q  default          []      None
#
# [406 rows x 37 columns]

# %%
node_properties  = bf.q.nodeProperties(properties="Domain_Name,NTP_Servers,Interfaces").answer().frame()
node_properties
# Out:
#            Node Domain_Name  \
# 0        nkr-gw        None
# 1     bnecore-2        None
# 2     dwncore-2        None
# 3     sydcore-2        None
# 4     sydcore-1        None
# ..          ...         ...
# 138   dwncore-1        None
# 139  meeknodegw        None
# 140    nmnnode1        None
# 141    hoenode1        None
# 142    echnode0        None
#
#                                                  Interfaces NTP_Servers
# 0                            ['eth0', 'eth1', 'eth2', 'lo']          []
# 1    ['eth0', 'eth1', 'eth2', 'eth3', 'eth4', 'eth5', 'lo']          []
# 2    ['eth0', 'eth1', 'eth2', 'eth3', 'eth4', 'eth5', 'lo']          []
# 3    ['eth0', 'eth1', 'eth2', 'eth3', 'eth4', 'eth5', 'lo']          []
# 4    ['eth0', 'eth1', 'eth2', 'eth3', 'eth4', 'eth5', 'lo']          []
# ..                                                      ...         ...
# 138  ['eth0', 'eth1', 'eth2', 'eth3', 'eth4', 'eth5', 'lo']          []
# 139                  ['eth0', 'eth1', 'eth2', 'eth3', 'lo']          []
# 140                                                ['eth0']          []
# 141                                                ['eth0']          []
# 142                                                ['eth0']          []
#
# [143 rows x 4 columns]

# %%
# Fetch specific properties of Loopback interfaces
bf.q.interfaceProperties(interfaces="/eth/", properties="Bandwidth,VRF,Primary_Address").answer().frame()
# Out:
#            Interface      Bandwidth   Primary_Address      VRF
# 0    adlcore-1[eth0]  10000000000.0    10.21.9.193/30  default
# 1    adlcore-1[eth1]  10000000000.0   10.22.27.115/29  default
# 2    adlcore-1[eth2]  10000000000.0    10.22.11.73/29  default
# 3    adlcore-1[eth3]  10000000000.0    10.10.22.25/30  default
# 4    adlcore-1[eth4]  10000000000.0   10.10.10.198/30  default
# ..               ...            ...               ...      ...
# 345  wwanodegw[eth2]  10000000000.0  10.25.165.206/25  default
# 346  wwanodegw[eth3]  10000000000.0  10.25.160.146/24  default
# 347     yrv-gw[eth0]  10000000000.0  10.22.217.196/29  default
# 348     yrv-gw[eth1]  10000000000.0  10.22.221.181/29  default
# 349     yrv-gw[eth2]  10000000000.0  10.23.208.165/29  default
#
# [350 rows x 4 columns]

# %%
# Get layer 3 edges
for i in node_properties.Node:
    print(i)
    print(bf.q.edges(nodes=i).answer().frame())
    print(' ')
# Out:
# nkr-gw
#       Interface               IPs Remote_Interface        Remote_IPs
# 0  nkr-gw[eth0]  ['10.22.93.123']  dwncore-1[eth1]  ['10.22.93.121']
# 1  nkr-gw[eth1]  ['10.23.91.121']    eme-nkr[eth0]  ['10.23.91.126']
# 2  nkr-gw[eth1]  ['10.23.91.121']    ess-nkr[eth0]  ['10.23.91.124']
# 3  nkr-gw[eth2]  ['10.22.83.189']  dwncore-2[eth4]  ['10.22.83.186']
#
# bnecore-2
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  bnecore-2[eth0]  ['10.22.126.109']     sun-gw[eth1]  ['10.22.126.107']
# 1  bnecore-2[eth1]   ['10.22.126.89']     byo-gw[eth0]   ['10.22.126.92']
# 2  bnecore-2[eth2]    ['10.20.99.61']     mkyagg[eth0]    ['10.20.99.62']
# 3  bnecore-2[eth3]   ['10.10.97.169']  sydcore-2[eth0]   ['10.10.97.170']
# 4  bnecore-2[eth4]    ['10.10.67.10']  dwncore-2[eth0]     ['10.10.67.9']
# 5  bnecore-2[eth5]  ['10.21.103.146']  bnecore-1[eth1]  ['10.21.103.145']
#
# dwncore-2
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  dwncore-2[eth0]    ['10.10.67.9']  bnecore-2[eth4]   ['10.10.67.10']
# 1  dwncore-2[eth1]  ['10.10.51.146']  percore-2[eth6]  ['10.10.51.145']
# 2  dwncore-2[eth2]   ['10.22.73.86']     plm-gw[eth2]   ['10.22.73.85']
# 3  dwncore-2[eth3]  ['10.21.80.249']  dwncore-1[eth3]  ['10.21.80.250']
# 4  dwncore-2[eth4]  ['10.22.83.186']     nkr-gw[eth2]  ['10.22.83.189']
# 5  dwncore-2[eth5]  ['10.20.77.105']    tncragg[eth1]  ['10.20.77.106']
#
# sydcore-2
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  sydcore-2[eth0]   ['10.10.97.170']  bnecore-2[eth3]   ['10.10.97.169']
# 1  sydcore-2[eth1]   ['10.22.140.49']     mbr-gw[eth1]   ['10.22.140.50']
# 2  sydcore-2[eth2]   ['10.22.136.30']     cht-gw[eth0]   ['10.22.136.26']
# 3  sydcore-2[eth3]  ['10.21.158.146']  sydcore-1[eth1]  ['10.21.158.145']
# 4  sydcore-2[eth4]  ['10.20.154.230']     dubagg[eth0]  ['10.20.154.229']
# 5  sydcore-2[eth5]   ['10.10.159.73']  cbrcore-2[eth0]   ['10.10.159.74']
#
# sydcore-1
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  sydcore-1[eth0]  ['10.22.137.252']     mbr-gw[eth2]  ['10.22.137.254']
# 1  sydcore-1[eth1]  ['10.21.158.145']  sydcore-2[eth3]  ['10.21.158.146']
# 2  sydcore-1[eth2]  ['10.22.151.116']     cht-gw[eth2]  ['10.22.151.115']
# 3  sydcore-1[eth3]   ['10.10.114.97']  bnecore-1[eth2]   ['10.10.114.98']
# 4  sydcore-1[eth4]  ['10.20.132.222']     dubagg[eth1]  ['10.20.132.221']
# 5  sydcore-1[eth5]  ['10.10.139.226']  cbrcore-1[eth2]  ['10.10.139.225']
#
# mrenodec
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  mrenodec[eth0]  ['10.24.15.61']     mreagg[eth2]  ['10.24.14.166']
# 1  mrenodec[eth1]  ['10.24.29.85']     mreagg[eth3]  ['10.24.29.109']
#
# dwdnode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  dwdnode2[eth0]  ['10.25.28.253']  dwdnodegw[eth3]  ['10.25.28.224']
#
# cmtnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  cmtnodegw[eth0]  ['10.25.218.111']     mkyagg[eth3]   ['10.25.218.59']
# 1  cmtnodegw[eth1]  ['10.25.152.247']   cmtnode1[eth0]  ['10.25.152.147']
# 2  cmtnodegw[eth2]   ['10.25.153.57']   cmtnode2[eth0]   ['10.25.153.51']
# 3  cmtnodegw[eth3]  ['10.25.152.118']   cmtnode0[eth0]   ['10.25.152.93']
#
# dwdnode1
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  dwdnode1[eth0]  ['10.25.31.39']  dwdnodegw[eth0]  ['10.25.31.24']
#
# wwanodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  wwanodegw[eth0]  ['10.25.230.150']     dubagg[eth2]   ['10.25.230.12']
# 1  wwanodegw[eth1]   ['10.25.163.79']   wwanode2[eth0]   ['10.25.163.44']
# 2  wwanodegw[eth2]  ['10.25.165.206']   wwanode0[eth0]  ['10.25.165.165']
# 3  wwanodegw[eth3]  ['10.25.160.146']   wwanode1[eth0]   ['10.25.160.57']
#
# percore-1
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  percore-1[eth0]  ['10.21.49.137']  percore-2[eth3]  ['10.21.49.138']
# 1  percore-1[eth1]   ['10.22.56.74']     fre-gw[eth2]   ['10.22.56.77']
# 2  percore-1[eth2]   ['10.22.56.85']     joo-gw[eth2]   ['10.22.56.86']
# 3  percore-1[eth3]   ['10.10.22.26']  adlcore-1[eth3]   ['10.10.22.25']
# 4  percore-1[eth4]  ['10.10.45.130']  dwncore-1[eth4]  ['10.10.45.129']
# 5  percore-1[eth5]   ['10.20.51.70']    gdtnagg[eth1]   ['10.20.51.69']
# 6  percore-1[eth6]   ['10.20.38.45']    krthagg[eth1]   ['10.20.38.46']
#
# hoenodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  hoenodegw[eth0]  ['10.25.229.243']     wagagg[eth5]  ['10.25.229.227']
# 1  hoenodegw[eth1]   ['10.25.161.70']   hoenode1[eth0]   ['10.25.161.89']
# 2  hoenodegw[eth2]   ['10.25.167.62']   hoenode0[eth0]  ['10.25.167.110']
#
# gdtnnodec
#          Interface              IPs Remote_Interface        Remote_IPs
# 0  gdtnnodec[eth0]  ['10.24.53.26']    gdtnagg[eth2]   ['10.24.53.86']
# 1  gdtnnodec[eth1]  ['10.24.59.17']    gdtnagg[eth3]  ['10.24.59.121']
#
# dwdnode0
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  dwdnode0[eth0]  ['10.25.24.65']  dwdnodegw[eth2]  ['10.25.24.70']
#
# percore-2
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  percore-2[eth0]    ['10.10.2.98']  adlcore-2[eth4]    ['10.10.2.97']
# 1  percore-2[eth1]  ['10.22.35.140']     fre-gw[eth0]  ['10.22.35.139']
# 2  percore-2[eth2]   ['10.22.34.33']     joo-gw[eth0]   ['10.22.34.36']
# 3  percore-2[eth3]  ['10.21.49.138']  percore-1[eth0]  ['10.21.49.137']
# 4  percore-2[eth4]   ['10.20.54.81']    krthagg[eth0]   ['10.20.54.82']
# 5  percore-2[eth5]  ['10.20.56.153']    gdtnagg[eth0]  ['10.20.56.154']
# 6  percore-2[eth6]  ['10.10.51.145']  dwncore-2[eth1]  ['10.10.51.146']
#
# mkyagg
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  mkyagg[eth0]    ['10.20.99.62']  bnecore-2[eth2]    ['10.20.99.61']
# 1  mkyagg[eth1]    ['10.20.98.65']  bnecore-1[eth5]    ['10.20.98.66']
# 2  mkyagg[eth2]  ['10.25.217.156']  dwdnodegw[eth1]  ['10.25.217.117']
# 3  mkyagg[eth3]   ['10.25.218.59']  cmtnodegw[eth0]  ['10.25.218.111']
# 4  mkyagg[eth4]   ['10.25.223.44']  infnodegw[eth0]   ['10.25.223.93']
# 5  mkyagg[eth5]  ['10.24.120.126']   mkynodec[eth0]  ['10.24.120.180']
# 6  mkyagg[eth6]   ['10.24.124.51']   mkynodec[eth1]  ['10.24.125.240']
#
# wlwnodegw
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  wlwnodegw[eth0]  ['10.25.212.59']    tncragg[eth6]  ['10.25.212.47']
# 1  wlwnodegw[eth1]   ['10.25.21.72']   wlwnode0[eth0]  ['10.25.21.123']
# 2  wlwnodegw[eth2]   ['10.25.22.13']   wlwnode1[eth0]   ['10.25.22.25']
#
# yrv-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  yrv-gw[eth0]  ['10.22.217.196']  melcore-2[eth3]  ['10.22.217.197']
# 1  yrv-gw[eth1]  ['10.22.221.181']  melcore-1[eth4]  ['10.22.221.180']
# 2  yrv-gw[eth2]  ['10.23.208.165']    eme-yrv[eth0]  ['10.23.208.164']
# 3  yrv-gw[eth2]  ['10.23.208.165']    ess-yrv[eth0]  ['10.23.208.161']
#
# eme-cht
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  eme-cht[eth0]  ['10.23.142.134']     cht-gw[eth1]  ['10.23.142.132']
# 1  eme-cht[eth0]  ['10.23.142.134']    ess-cht[eth0]  ['10.23.142.133']
#
# eme-edn
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  eme-edn[eth0]  ['10.23.4.148']     edn-gw[eth2]  ['10.23.4.150']
# 1  eme-edn[eth0]  ['10.23.4.148']    ess-edn[eth0]  ['10.23.4.149']
#
# mreagg
#       Interface               IPs  Remote_Interface         Remote_IPs
# 0  mreagg[eth0]  ['10.20.18.246']   adlcore-2[eth5]   ['10.20.18.245']
# 1  mreagg[eth1]  ['10.20.12.134']   adlcore-1[eth5]   ['10.20.12.133']
# 2  mreagg[eth2]  ['10.24.14.166']    mrenodec[eth0]    ['10.24.15.61']
# 3  mreagg[eth3]  ['10.24.29.109']    mrenodec[eth1]    ['10.24.29.85']
# 4  mreagg[eth4]   ['10.25.193.6']  cbpdnodegw[eth0]   ['10.25.193.77']
# 5  mreagg[eth5]  ['10.25.196.42']  inkanodegw[eth0]  ['10.25.196.172']
#
# eme-mbr
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  eme-mbr[eth0]  ['10.23.147.26']    ess-mbr[eth0]  ['10.23.147.28']
# 1  eme-mbr[eth0]  ['10.23.147.26']     mbr-gw[eth0]  ['10.23.147.29']
#
# eme-yrv
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  eme-yrv[eth0]  ['10.23.208.164']    ess-yrv[eth0]  ['10.23.208.161']
# 1  eme-yrv[eth0]  ['10.23.208.164']     yrv-gw[eth2]  ['10.23.208.165']
#
# inkanodegw
#           Interface                IPs Remote_Interface        Remote_IPs
# 0  inkanodegw[eth0]  ['10.25.196.172']     mreagg[eth5]  ['10.25.196.42']
# 1  inkanodegw[eth1]    ['10.25.3.194']  inkanode2[eth0]   ['10.25.3.141']
# 2  inkanodegw[eth2]    ['10.25.7.137']  inkanode0[eth0]   ['10.25.7.174']
# 3  inkanodegw[eth3]    ['10.25.4.129']  inkanode1[eth0]   ['10.25.4.154']
#
# milagg
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  milagg[eth0]  ['10.20.202.166']  melcore-2[eth4]  ['10.20.202.165']
# 1  milagg[eth1]   ['10.20.209.98']  melcore-1[eth6]   ['10.20.209.97']
# 2  milagg[eth2]   ['10.25.243.13']  hsmnodegw[eth0]   ['10.25.243.88']
# 3  milagg[eth3]   ['10.24.201.93']   milnodec[eth0]  ['10.24.201.153']
# 4  milagg[eth4]  ['10.24.204.253']   milnodec[eth1]   ['10.24.204.90']
# 5  milagg[eth5]  ['10.25.241.152']  echnodegw[eth0]   ['10.25.241.50']
#
# nmnnode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  nmnnode2[eth0]  ['10.25.72.213']  nmnnodegw[eth1]  ['10.25.72.217']
#
# krthnodec
#          Interface              IPs Remote_Interface        Remote_IPs
# 0  krthnodec[eth0]   ['10.24.47.9']    krthagg[eth4]   ['10.24.47.10']
# 1  krthnodec[eth1]  ['10.24.42.58']    krthagg[eth5]  ['10.24.42.216']
#
# trinode0
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  trinode0[eth0]  ['10.25.144.226']  trinodegw[eth1]  ['10.25.144.222']
#
# ess-plm
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  ess-plm[eth0]  ['10.23.82.41']    eme-plm[eth0]  ['10.23.82.42']
# 1  ess-plm[eth0]  ['10.23.82.41']     plm-gw[eth0]  ['10.23.82.44']
#
# ess-kng
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  ess-kng[eth0]  ['10.23.191.5']    eme-kng[eth0]  ['10.23.191.3']
# 1  ess-kng[eth0]  ['10.23.191.5']     kng-gw[eth0]  ['10.23.191.4']
#
# trinode2
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  trinode2[eth0]  ['10.25.146.204']  trinodegw[eth2]  ['10.25.146.124']
#
# ess-rch
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  ess-rch[eth0]  ['10.23.196.177']    eme-rch[eth0]  ['10.23.196.181']
# 1  ess-rch[eth0]  ['10.23.196.177']     rch-gw[eth0]  ['10.23.196.180']
#
# ess-tor
#        Interface              IPs Remote_Interface        Remote_IPs
# 0  ess-tor[eth0]  ['10.23.13.98']    eme-tor[eth0]  ['10.23.13.100']
# 1  ess-tor[eth0]  ['10.23.13.98']     tor-gw[eth1]   ['10.23.13.97']
#
# nmnnodegw
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  nmnnodegw[eth0]  ['10.25.207.22']    krthagg[eth3]  ['10.25.207.39']
# 1  nmnnodegw[eth1]  ['10.25.72.217']   nmnnode2[eth0]  ['10.25.72.213']
# 2  nmnnodegw[eth2]  ['10.25.77.240']   nmnnode1[eth0]  ['10.25.77.221']
# 3  nmnnodegw[eth3]  ['10.25.75.120']   nmnnode0[eth0]   ['10.25.75.67']
#
# cmtnode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  cmtnode2[eth0]  ['10.25.153.51']  cmtnodegw[eth2]  ['10.25.153.57']
#
# frknode0
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  frknode0[eth0]  ['10.25.56.139']  frknodegw[eth1]  ['10.25.56.145']
#
# inkanode0
#          Interface              IPs  Remote_Interface       Remote_IPs
# 0  inkanode0[eth0]  ['10.25.7.174']  inkanodegw[eth2]  ['10.25.7.137']
#
# brwnode0
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  brwnode0[eth0]  ['10.25.11.81']  brwnodegw[eth2]  ['10.25.11.96']
#
# infnode0
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  infnode0[eth0]  ['10.25.157.77']  infnodegw[eth2]  ['10.25.157.82']
#
# inkanode2
#          Interface              IPs  Remote_Interface       Remote_IPs
# 0  inkanode2[eth0]  ['10.25.3.141']  inkanodegw[eth1]  ['10.25.3.194']
#
# dwdnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  dwdnodegw[eth0]    ['10.25.31.24']   dwdnode1[eth0]    ['10.25.31.39']
# 1  dwdnodegw[eth1]  ['10.25.217.117']     mkyagg[eth2]  ['10.25.217.156']
# 2  dwdnodegw[eth2]    ['10.25.24.70']   dwdnode0[eth0]    ['10.25.24.65']
# 3  dwdnodegw[eth3]   ['10.25.28.224']   dwdnode2[eth0]   ['10.25.28.253']
#
# echnode2
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  echnode2[eth0]  ['10.25.118.162']  echnodegw[eth1]  ['10.25.118.175']
#
# inkanode1
#          Interface              IPs  Remote_Interface       Remote_IPs
# 0  inkanode1[eth0]  ['10.25.4.154']  inkanodegw[eth3]  ['10.25.4.129']
#
# brwnode1
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  brwnode1[eth0]  ['10.25.15.89']  brwnodegw[eth1]  ['10.25.15.38']
#
# cht-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  cht-gw[eth0]   ['10.22.136.26']  sydcore-2[eth2]   ['10.22.136.30']
# 1  cht-gw[eth1]  ['10.23.142.132']    eme-cht[eth0]  ['10.23.142.134']
# 2  cht-gw[eth1]  ['10.23.142.132']    ess-cht[eth0]  ['10.23.142.133']
# 3  cht-gw[eth2]  ['10.22.151.115']  sydcore-1[eth2]  ['10.22.151.116']
#
# klbnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  klbnodegw[eth0]  ['10.25.203.164']    gdtnagg[eth5]  ['10.25.203.216']
# 1  klbnodegw[eth1]   ['10.25.78.146']   klbnode0[eth0]    ['10.25.78.50']
# 2  klbnodegw[eth2]    ['10.25.72.26']   klbnode1[eth0]    ['10.25.72.51']
#
# krthagg
#        Interface               IPs Remote_Interface         Remote_IPs
# 0  krthagg[eth0]   ['10.20.54.82']  percore-2[eth4]    ['10.20.54.81']
# 1  krthagg[eth1]   ['10.20.38.46']  percore-1[eth6]    ['10.20.38.45']
# 2  krthagg[eth2]  ['10.25.205.84']  brwnodegw[eth0]  ['10.25.205.112']
# 3  krthagg[eth3]  ['10.25.207.39']  nmnnodegw[eth0]   ['10.25.207.22']
# 4  krthagg[eth4]   ['10.24.47.10']  krthnodec[eth0]     ['10.24.47.9']
# 5  krthagg[eth5]  ['10.24.42.216']  krthnodec[eth1]    ['10.24.42.58']
#
# infnode1
#         Interface               IPs Remote_Interface         Remote_IPs
# 0  infnode1[eth0]  ['10.25.154.31']  infnodegw[eth1]  ['10.25.154.156']
#
# eme-joo
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  eme-joo[eth0]  ['10.23.39.110']    ess-joo[eth0]  ['10.23.39.106']
# 1  eme-joo[eth0]  ['10.23.39.110']     joo-gw[eth1]  ['10.23.39.108']
#
# ess-yrv
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  ess-yrv[eth0]  ['10.23.208.161']    eme-yrv[eth0]  ['10.23.208.164']
# 1  ess-yrv[eth0]  ['10.23.208.161']     yrv-gw[eth2]  ['10.23.208.165']
#
# tncragg
#        Interface                IPs Remote_Interface        Remote_IPs
# 0  tncragg[eth0]     ['10.20.81.6']  dwncore-1[eth5]    ['10.20.81.5']
# 1  tncragg[eth1]   ['10.20.77.106']  dwncore-2[eth5]  ['10.20.77.105']
# 2  tncragg[eth2]    ['10.25.211.9']  pamnodegw[eth1]  ['10.25.211.99']
# 3  tncragg[eth3]   ['10.24.93.221']  tncrnodec[eth0]  ['10.24.93.191']
# 4  tncragg[eth4]   ['10.24.92.171']  tncrnodec[eth1]  ['10.24.92.191']
# 5  tncragg[eth5]  ['10.25.209.106']  trinodegw[eth0]   ['10.25.209.8']
# 6  tncragg[eth6]   ['10.25.212.47']  wlwnodegw[eth0]  ['10.25.212.59']
#
# ess-mbr
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  ess-mbr[eth0]  ['10.23.147.28']    eme-mbr[eth0]  ['10.23.147.26']
# 1  ess-mbr[eth0]  ['10.23.147.28']     mbr-gw[eth0]  ['10.23.147.29']
#
# eme-sun
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  eme-sun[eth0]  ['10.23.115.35']    ess-sun[eth0]  ['10.23.115.34']
# 1  eme-sun[eth0]  ['10.23.115.35']     sun-gw[eth0]  ['10.23.115.37']
#
# byo-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  byo-gw[eth0]   ['10.22.126.92']  bnecore-2[eth1]   ['10.22.126.89']
# 1  byo-gw[eth1]  ['10.23.119.124']    eme-byo[eth0]  ['10.23.119.122']
# 2  byo-gw[eth1]  ['10.23.119.124']    ess-byo[eth0]  ['10.23.119.125']
# 3  byo-gw[eth2]   ['10.22.106.26']  bnecore-1[eth4]   ['10.22.106.30']
#
# hobnodec
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  hobnodec[eth0]  ['10.24.244.164']     hobagg[eth3]  ['10.24.245.204']
# 1  hobnodec[eth1]  ['10.24.225.109']     hobagg[eth4]   ['10.24.225.23']
#
# pamnode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  pamnode2[eth0]  ['10.25.86.136']  pamnodegw[eth2]  ['10.25.86.142']
#
# engnode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  engnode2[eth0]  ['10.25.34.227']  engnodegw[eth1]  ['10.25.34.154']
#
# fre-gw
#       Interface               IPs Remote_Interface        Remote_IPs
# 0  fre-gw[eth0]  ['10.22.35.139']  percore-2[eth1]  ['10.22.35.140']
# 1  fre-gw[eth1]  ['10.23.33.124']    eme-fre[eth0]  ['10.23.33.126']
# 2  fre-gw[eth1]  ['10.23.33.124']    ess-fre[eth0]  ['10.23.33.125']
# 3  fre-gw[eth2]   ['10.22.56.77']  percore-1[eth1]   ['10.22.56.74']
#
# joo-gw
#       Interface               IPs Remote_Interface        Remote_IPs
# 0  joo-gw[eth0]   ['10.22.34.36']  percore-2[eth2]   ['10.22.34.33']
# 1  joo-gw[eth1]  ['10.23.39.108']    eme-joo[eth0]  ['10.23.39.110']
# 2  joo-gw[eth1]  ['10.23.39.108']    ess-joo[eth0]  ['10.23.39.106']
# 3  joo-gw[eth2]   ['10.22.56.86']  percore-1[eth2]   ['10.22.56.85']
#
# ess-nkr
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  ess-nkr[eth0]  ['10.23.91.124']    eme-nkr[eth0]  ['10.23.91.126']
# 1  ess-nkr[eth0]  ['10.23.91.124']     nkr-gw[eth1]  ['10.23.91.121']
#
# engnode0
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  engnode0[eth0]  ['10.25.39.81']  engnodegw[eth3]  ['10.25.39.11']
#
# eme-rch
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  eme-rch[eth0]  ['10.23.196.181']    ess-rch[eth0]  ['10.23.196.177']
# 1  eme-rch[eth0]  ['10.23.196.181']     rch-gw[eth0]  ['10.23.196.180']
#
# eme-tor
#        Interface               IPs Remote_Interface       Remote_IPs
# 0  eme-tor[eth0]  ['10.23.13.100']    ess-tor[eth0]  ['10.23.13.98']
# 1  eme-tor[eth0]  ['10.23.13.100']     tor-gw[eth1]  ['10.23.13.97']
#
# melcore-1
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  melcore-1[eth0]  ['10.22.213.173']     rch-gw[eth2]  ['10.22.213.170']
# 1  melcore-1[eth1]  ['10.21.215.241']  melcore-2[eth6]  ['10.21.215.242']
# 2  melcore-1[eth2]   ['10.10.10.197']  adlcore-1[eth4]   ['10.10.10.198']
# 3  melcore-1[eth3]  ['10.10.186.254']  cbrcore-1[eth4]  ['10.10.186.253']
# 4  melcore-1[eth4]  ['10.22.221.180']     yrv-gw[eth1]  ['10.22.221.181']
# 5  melcore-1[eth5]   ['10.20.197.29']     hobagg[eth1]   ['10.20.197.30']
# 6  melcore-1[eth6]   ['10.20.209.97']     milagg[eth1]   ['10.20.209.98']
#
# trinode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  trinode1[eth0]  ['10.25.150.16']  trinodegw[eth3]  ['10.25.150.50']
#
# ungnode2
#         Interface              IPs Remote_Interface         Remote_IPs
# 0  ungnode2[eth0]  ['10.25.164.5']  ungnodegw[eth2]  ['10.25.164.152']
#
# eme-nkr
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  eme-nkr[eth0]  ['10.23.91.126']    ess-nkr[eth0]  ['10.23.91.124']
# 1  eme-nkr[eth0]  ['10.23.91.126']     nkr-gw[eth1]  ['10.23.91.121']
#
# bnecore-1
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  bnecore-1[eth0]  ['10.22.115.230']     sun-gw[eth2]  ['10.22.115.225']
# 1  bnecore-1[eth1]  ['10.21.103.145']  bnecore-2[eth5]  ['10.21.103.146']
# 2  bnecore-1[eth2]   ['10.10.114.98']  sydcore-1[eth3]   ['10.10.114.97']
# 3  bnecore-1[eth3]    ['10.10.65.26']  dwncore-1[eth2]    ['10.10.65.25']
# 4  bnecore-1[eth4]   ['10.22.106.30']     byo-gw[eth2]   ['10.22.106.26']
# 5  bnecore-1[eth5]    ['10.20.98.66']     mkyagg[eth1]    ['10.20.98.65']
#
# ungnode0
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  ungnode0[eth0]  ['10.25.166.117']  ungnodegw[eth0]  ['10.25.166.102']
#
# melcore-2
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  melcore-2[eth0]    ['10.10.9.205']  adlcore-2[eth3]    ['10.10.9.206']
# 1  melcore-2[eth1]   ['10.10.184.21']  cbrcore-2[eth4]   ['10.10.184.22']
# 2  melcore-2[eth2]   ['10.22.223.93']     rch-gw[eth1]   ['10.22.223.90']
# 3  melcore-2[eth3]  ['10.22.217.197']     yrv-gw[eth0]  ['10.22.217.196']
# 4  melcore-2[eth4]  ['10.20.202.165']     milagg[eth0]  ['10.20.202.166']
# 5  melcore-2[eth5]   ['10.20.202.33']     hobagg[eth0]   ['10.20.202.34']
# 6  melcore-2[eth6]  ['10.21.215.242']  melcore-1[eth1]  ['10.21.215.241']
#
# adlcore-2
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  adlcore-2[eth0]    ['10.22.3.82']     tor-gw[eth0]    ['10.22.3.86']
# 1  adlcore-2[eth1]   ['10.22.19.89']     edn-gw[eth0]   ['10.22.19.93']
# 2  adlcore-2[eth2]   ['10.21.9.194']  adlcore-1[eth0]   ['10.21.9.193']
# 3  adlcore-2[eth3]   ['10.10.9.206']  melcore-2[eth0]   ['10.10.9.205']
# 4  adlcore-2[eth4]    ['10.10.2.97']  percore-2[eth0]    ['10.10.2.98']
# 5  adlcore-2[eth5]  ['10.20.18.245']     mreagg[eth0]  ['10.20.18.246']
#
# cbpdnodegw
#           Interface               IPs Remote_Interface        Remote_IPs
# 0  cbpdnodegw[eth0]  ['10.25.193.77']     mreagg[eth4]   ['10.25.193.6']
# 1  cbpdnodegw[eth1]  ['10.25.69.164']  cbpdnode1[eth0]  ['10.25.69.221']
# 2  cbpdnodegw[eth2]   ['10.25.68.57']  cbpdnode0[eth0]   ['10.25.68.52']
#
# frknodegw
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  frknodegw[eth0]  ['10.25.250.70']     hobagg[eth2]  ['10.25.250.54']
# 1  frknodegw[eth1]  ['10.25.56.145']   frknode0[eth0]  ['10.25.56.139']
# 2  frknodegw[eth2]  ['10.25.58.254']   frknode1[eth0]  ['10.25.58.108']
# 3  frknodegw[eth3]  ['10.25.59.155']   frknode2[eth0]   ['10.25.59.96']
#
# adlcore-1
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  adlcore-1[eth0]   ['10.21.9.193']  adlcore-2[eth2]   ['10.21.9.194']
# 1  adlcore-1[eth1]  ['10.22.27.115']     tor-gw[eth2]  ['10.22.27.116']
# 2  adlcore-1[eth2]   ['10.22.11.73']     edn-gw[eth1]   ['10.22.11.75']
# 3  adlcore-1[eth3]   ['10.10.22.25']  percore-1[eth3]   ['10.10.22.26']
# 4  adlcore-1[eth4]  ['10.10.10.198']  melcore-1[eth2]  ['10.10.10.197']
# 5  adlcore-1[eth5]  ['10.20.12.133']     mreagg[eth1]  ['10.20.12.134']
#
# echnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  echnodegw[eth0]   ['10.25.241.50']     milagg[eth5]  ['10.25.241.152']
# 1  echnodegw[eth1]  ['10.25.118.175']   echnode2[eth0]  ['10.25.118.162']
# 2  echnodegw[eth2]   ['10.25.119.46']   echnode0[eth0]   ['10.25.119.99']
# 3  echnodegw[eth3]   ['10.25.116.20']   echnode1[eth0]    ['10.25.116.3']
#
# pamnodegw
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  pamnodegw[eth0]  ['10.25.85.105']   pamnode0[eth0]   ['10.25.85.77']
# 1  pamnodegw[eth1]  ['10.25.211.99']    tncragg[eth2]   ['10.25.211.9']
# 2  pamnodegw[eth2]  ['10.25.86.142']   pamnode2[eth0]  ['10.25.86.136']
# 3  pamnodegw[eth3]  ['10.25.85.221']   pamnode1[eth0]  ['10.25.85.191']
#
# trinodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  trinodegw[eth0]    ['10.25.209.8']    tncragg[eth5]  ['10.25.209.106']
# 1  trinodegw[eth1]  ['10.25.144.222']   trinode0[eth0]  ['10.25.144.226']
# 2  trinodegw[eth2]  ['10.25.146.124']   trinode2[eth0]  ['10.25.146.204']
# 3  trinodegw[eth3]   ['10.25.150.50']   trinode1[eth0]   ['10.25.150.16']
#
# wwanode0
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  wwanode0[eth0]  ['10.25.165.165']  wwanodegw[eth2]  ['10.25.165.206']
#
# meeknode1
#          Interface                IPs  Remote_Interface         Remote_IPs
# 0  meeknode1[eth0]  ['10.25.140.173']  meeknodegw[eth2]  ['10.25.140.169']
#
# meeknode2
#          Interface                IPs  Remote_Interface         Remote_IPs
# 0  meeknode2[eth0]  ['10.25.137.132']  meeknodegw[eth1]  ['10.25.137.183']
#
# cbpdnode1
#          Interface               IPs  Remote_Interface        Remote_IPs
# 0  cbpdnode1[eth0]  ['10.25.69.221']  cbpdnodegw[eth1]  ['10.25.69.164']
#
# nmnnode0
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  nmnnode0[eth0]  ['10.25.75.67']  nmnnodegw[eth3]  ['10.25.75.120']
#
# ess-byo
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  ess-byo[eth0]  ['10.23.119.125']     byo-gw[eth1]  ['10.23.119.124']
# 1  ess-byo[eth0]  ['10.23.119.125']    eme-byo[eth0]  ['10.23.119.122']
#
# wwanode1
#         Interface               IPs Remote_Interface         Remote_IPs
# 0  wwanode1[eth0]  ['10.25.160.57']  wwanodegw[eth3]  ['10.25.160.146']
#
# wwanode2
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  wwanode2[eth0]  ['10.25.163.44']  wwanodegw[eth1]  ['10.25.163.79']
#
# pamnode0
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  pamnode0[eth0]  ['10.25.85.77']  pamnodegw[eth0]  ['10.25.85.105']
#
# pamnode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  pamnode1[eth0]  ['10.25.85.191']  pamnodegw[eth3]  ['10.25.85.221']
#
# milnodec
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  milnodec[eth0]  ['10.24.201.153']     milagg[eth3]   ['10.24.201.93']
# 1  milnodec[eth1]   ['10.24.204.90']     milagg[eth4]  ['10.24.204.253']
#
# tor-gw
#       Interface               IPs Remote_Interface        Remote_IPs
# 0  tor-gw[eth0]    ['10.22.3.86']  adlcore-2[eth0]    ['10.22.3.82']
# 1  tor-gw[eth1]   ['10.23.13.97']    eme-tor[eth0]  ['10.23.13.100']
# 2  tor-gw[eth1]   ['10.23.13.97']    ess-tor[eth0]   ['10.23.13.98']
# 3  tor-gw[eth2]  ['10.22.27.116']  adlcore-1[eth1]  ['10.22.27.115']
#
# ess-fre
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  ess-fre[eth0]  ['10.23.33.125']    eme-fre[eth0]  ['10.23.33.126']
# 1  ess-fre[eth0]  ['10.23.33.125']     fre-gw[eth1]  ['10.23.33.124']
#
# kng-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  kng-gw[eth0]    ['10.23.191.4']    eme-kng[eth0]    ['10.23.191.3']
# 1  kng-gw[eth0]    ['10.23.191.4']    ess-kng[eth0]    ['10.23.191.5']
# 2  kng-gw[eth1]  ['10.22.184.172']  cbrcore-2[eth1]  ['10.22.184.169']
# 3  kng-gw[eth2]  ['10.22.167.226']  cbrcore-1[eth0]  ['10.22.167.225']
#
# mkynodec
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  mkynodec[eth0]  ['10.24.120.180']     mkyagg[eth5]  ['10.24.120.126']
# 1  mkynodec[eth1]  ['10.24.125.240']     mkyagg[eth6]   ['10.24.124.51']
#
# ess-cht
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  ess-cht[eth0]  ['10.23.142.133']     cht-gw[eth1]  ['10.23.142.132']
# 1  ess-cht[eth0]  ['10.23.142.133']    eme-cht[eth0]  ['10.23.142.134']
#
# ess-edn
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  ess-edn[eth0]  ['10.23.4.149']     edn-gw[eth2]  ['10.23.4.150']
# 1  ess-edn[eth0]  ['10.23.4.149']    eme-edn[eth0]  ['10.23.4.148']
#
# frknode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  frknode1[eth0]  ['10.25.58.108']  frknodegw[eth2]  ['10.25.58.254']
#
# eme-plm
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  eme-plm[eth0]  ['10.23.82.42']    ess-plm[eth0]  ['10.23.82.41']
# 1  eme-plm[eth0]  ['10.23.82.42']     plm-gw[eth0]  ['10.23.82.44']
#
# eme-kng
#        Interface              IPs Remote_Interface       Remote_IPs
# 0  eme-kng[eth0]  ['10.23.191.3']    ess-kng[eth0]  ['10.23.191.5']
# 1  eme-kng[eth0]  ['10.23.191.3']     kng-gw[eth0]  ['10.23.191.4']
#
# hoenode0
#         Interface                IPs Remote_Interface        Remote_IPs
# 0  hoenode0[eth0]  ['10.25.167.110']  hoenodegw[eth2]  ['10.25.167.62']
#
# echnode1
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  echnode1[eth0]  ['10.25.116.3']  echnodegw[eth3]  ['10.25.116.20']
#
# sun-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  sun-gw[eth0]   ['10.23.115.37']    eme-sun[eth0]   ['10.23.115.35']
# 1  sun-gw[eth0]   ['10.23.115.37']    ess-sun[eth0]   ['10.23.115.34']
# 2  sun-gw[eth1]  ['10.22.126.107']  bnecore-2[eth0]  ['10.22.126.109']
# 3  sun-gw[eth2]  ['10.22.115.225']  bnecore-1[eth0]  ['10.22.115.230']
#
# ungnode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  ungnode1[eth0]  ['10.25.165.10']  ungnodegw[eth3]  ['10.25.165.95']
#
# mbr-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  mbr-gw[eth0]   ['10.23.147.29']    eme-mbr[eth0]   ['10.23.147.26']
# 1  mbr-gw[eth0]   ['10.23.147.29']    ess-mbr[eth0]   ['10.23.147.28']
# 2  mbr-gw[eth1]   ['10.22.140.50']  sydcore-2[eth1]   ['10.22.140.49']
# 3  mbr-gw[eth2]  ['10.22.137.254']  sydcore-1[eth0]  ['10.22.137.252']
#
# eme-byo
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  eme-byo[eth0]  ['10.23.119.122']     byo-gw[eth1]  ['10.23.119.124']
# 1  eme-byo[eth0]  ['10.23.119.122']    ess-byo[eth0]  ['10.23.119.125']
#
# brd-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  brd-gw[eth0]  ['10.22.186.202']  cbrcore-2[eth2]  ['10.22.186.205']
# 1  brd-gw[eth1]  ['10.22.178.133']  cbrcore-1[eth3]  ['10.22.178.130']
# 2  brd-gw[eth2]  ['10.23.180.214']    eme-brd[eth0]  ['10.23.180.211']
# 3  brd-gw[eth2]  ['10.23.180.214']    ess-brd[eth0]  ['10.23.180.209']
#
# engnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  engnodegw[eth0]  ['10.25.231.221']     dubagg[eth3]  ['10.25.231.197']
# 1  engnodegw[eth1]   ['10.25.34.154']   engnode2[eth0]   ['10.25.34.227']
# 2  engnodegw[eth2]    ['10.25.32.37']   engnode1[eth0]     ['10.25.32.5']
# 3  engnodegw[eth3]    ['10.25.39.11']   engnode0[eth0]    ['10.25.39.81']
#
# ess-brd
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  ess-brd[eth0]  ['10.23.180.209']     brd-gw[eth2]  ['10.23.180.214']
# 1  ess-brd[eth0]  ['10.23.180.209']    eme-brd[eth0]  ['10.23.180.211']
#
# engnode1
#         Interface             IPs Remote_Interface       Remote_IPs
# 0  engnode1[eth0]  ['10.25.32.5']  engnodegw[eth2]  ['10.25.32.37']
#
# cmtnode1
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  cmtnode1[eth0]  ['10.25.152.147']  cmtnodegw[eth1]  ['10.25.152.247']
#
# klbnode0
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  klbnode0[eth0]  ['10.25.78.50']  klbnodegw[eth1]  ['10.25.78.146']
#
# wlwnode0
#         Interface               IPs Remote_Interface       Remote_IPs
# 0  wlwnode0[eth0]  ['10.25.21.123']  wlwnodegw[eth1]  ['10.25.21.72']
#
# hsmnode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  hsmnode1[eth0]  ['10.25.50.174']  hsmnodegw[eth2]  ['10.25.50.234']
#
# edn-gw
#       Interface              IPs Remote_Interface       Remote_IPs
# 0  edn-gw[eth0]  ['10.22.19.93']  adlcore-2[eth1]  ['10.22.19.89']
# 1  edn-gw[eth1]  ['10.22.11.75']  adlcore-1[eth2]  ['10.22.11.73']
# 2  edn-gw[eth2]  ['10.23.4.150']    eme-edn[eth0]  ['10.23.4.148']
# 3  edn-gw[eth2]  ['10.23.4.150']    ess-edn[eth0]  ['10.23.4.149']
#
# hsmnode0
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  hsmnode0[eth0]  ['10.25.55.207']  hsmnodegw[eth1]  ['10.25.55.186']
#
# infnodegw
#          Interface                IPs Remote_Interface        Remote_IPs
# 0  infnodegw[eth0]   ['10.25.223.93']     mkyagg[eth4]  ['10.25.223.44']
# 1  infnodegw[eth1]  ['10.25.154.156']   infnode1[eth0]  ['10.25.154.31']
# 2  infnodegw[eth2]   ['10.25.157.82']   infnode0[eth0]  ['10.25.157.77']
#
# wlwnode1
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  wlwnode1[eth0]  ['10.25.22.25']  wlwnodegw[eth2]  ['10.25.22.13']
#
# cbpdnode0
#          Interface              IPs  Remote_Interface       Remote_IPs
# 0  cbpdnode0[eth0]  ['10.25.68.52']  cbpdnodegw[eth2]  ['10.25.68.57']
#
# brwnodegw
#          Interface                IPs Remote_Interface        Remote_IPs
# 0  brwnodegw[eth0]  ['10.25.205.112']    krthagg[eth2]  ['10.25.205.84']
# 1  brwnodegw[eth1]    ['10.25.15.38']   brwnode1[eth0]   ['10.25.15.89']
# 2  brwnodegw[eth2]    ['10.25.11.96']   brwnode0[eth0]   ['10.25.11.81']
#
# klbnode1
#         Interface              IPs Remote_Interface       Remote_IPs
# 0  klbnode1[eth0]  ['10.25.72.51']  klbnodegw[eth2]  ['10.25.72.26']
#
# hobagg
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  hobagg[eth0]   ['10.20.202.34']  melcore-2[eth5]   ['10.20.202.33']
# 1  hobagg[eth1]   ['10.20.197.30']  melcore-1[eth5]   ['10.20.197.29']
# 2  hobagg[eth2]   ['10.25.250.54']  frknodegw[eth0]   ['10.25.250.70']
# 3  hobagg[eth3]  ['10.24.245.204']   hobnodec[eth0]  ['10.24.244.164']
# 4  hobagg[eth4]   ['10.24.225.23']   hobnodec[eth1]  ['10.24.225.109']
#
# tncrnodec
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  tncrnodec[eth0]  ['10.24.93.191']    tncragg[eth3]  ['10.24.93.221']
# 1  tncrnodec[eth1]  ['10.24.92.191']    tncragg[eth4]  ['10.24.92.171']
#
# gdtnagg
#        Interface                IPs  Remote_Interface         Remote_IPs
# 0  gdtnagg[eth0]   ['10.20.56.154']   percore-2[eth5]   ['10.20.56.153']
# 1  gdtnagg[eth1]    ['10.20.51.69']   percore-1[eth5]    ['10.20.51.70']
# 2  gdtnagg[eth2]    ['10.24.53.86']   gdtnnodec[eth0]    ['10.24.53.26']
# 3  gdtnagg[eth3]   ['10.24.59.121']   gdtnnodec[eth1]    ['10.24.59.17']
# 4  gdtnagg[eth4]  ['10.25.202.222']  meeknodegw[eth0]   ['10.25.202.31']
# 5  gdtnagg[eth5]  ['10.25.203.216']   klbnodegw[eth0]  ['10.25.203.164']
#
# eme-fre
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  eme-fre[eth0]  ['10.23.33.126']    ess-fre[eth0]  ['10.23.33.125']
# 1  eme-fre[eth0]  ['10.23.33.126']     fre-gw[eth1]  ['10.23.33.124']
#
# wagagg
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  wagagg[eth0]   ['10.20.139.46']  cbrcore-2[eth5]   ['10.20.139.45']
# 1  wagagg[eth1]  ['10.20.154.246']  cbrcore-1[eth5]  ['10.20.154.245']
# 2  wagagg[eth2]   ['10.25.227.35']  ungnodegw[eth1]   ['10.25.227.50']
# 3  wagagg[eth3]  ['10.24.145.168']   wagnodec[eth0]  ['10.24.145.208']
# 4  wagagg[eth4]   ['10.24.131.11']   wagnodec[eth1]  ['10.24.130.251']
# 5  wagagg[eth5]  ['10.25.229.227']  hoenodegw[eth0]  ['10.25.229.243']
#
# dubnodec
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  dubnodec[eth0]   ['10.24.155.40']     dubagg[eth4]  ['10.24.154.248']
# 1  dubnodec[eth1]  ['10.24.141.161']     dubagg[eth5]  ['10.24.140.237']
#
# plm-gw
#       Interface               IPs Remote_Interface        Remote_IPs
# 0  plm-gw[eth0]   ['10.23.82.44']    eme-plm[eth0]   ['10.23.82.42']
# 1  plm-gw[eth0]   ['10.23.82.44']    ess-plm[eth0]   ['10.23.82.41']
# 2  plm-gw[eth1]  ['10.22.85.107']  dwncore-1[eth0]  ['10.22.85.105']
# 3  plm-gw[eth2]   ['10.22.73.85']  dwncore-2[eth2]   ['10.22.73.86']
#
# dubagg
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  dubagg[eth0]  ['10.20.154.229']  sydcore-2[eth4]  ['10.20.154.230']
# 1  dubagg[eth1]  ['10.20.132.221']  sydcore-1[eth4]  ['10.20.132.222']
# 2  dubagg[eth2]   ['10.25.230.12']  wwanodegw[eth0]  ['10.25.230.150']
# 3  dubagg[eth3]  ['10.25.231.197']  engnodegw[eth0]  ['10.25.231.221']
# 4  dubagg[eth4]  ['10.24.154.248']   dubnodec[eth0]   ['10.24.155.40']
# 5  dubagg[eth5]  ['10.24.140.237']   dubnodec[eth1]  ['10.24.141.161']
#
# frknode2
#         Interface              IPs Remote_Interface        Remote_IPs
# 0  frknode2[eth0]  ['10.25.59.96']  frknodegw[eth3]  ['10.25.59.155']
#
# ess-joo
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  ess-joo[eth0]  ['10.23.39.106']    eme-joo[eth0]  ['10.23.39.110']
# 1  ess-joo[eth0]  ['10.23.39.106']     joo-gw[eth1]  ['10.23.39.108']
#
# hsmnodegw
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  hsmnodegw[eth0]  ['10.25.243.88']     milagg[eth2]  ['10.25.243.13']
# 1  hsmnodegw[eth1]  ['10.25.55.186']   hsmnode0[eth0]  ['10.25.55.207']
# 2  hsmnodegw[eth2]  ['10.25.50.234']   hsmnode1[eth0]  ['10.25.50.174']
#
# cbrcore-2
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  cbrcore-2[eth0]   ['10.10.159.74']  sydcore-2[eth5]   ['10.10.159.73']
# 1  cbrcore-2[eth1]  ['10.22.184.169']     kng-gw[eth1]  ['10.22.184.172']
# 2  cbrcore-2[eth2]  ['10.22.186.205']     brd-gw[eth0]  ['10.22.186.202']
# 3  cbrcore-2[eth3]  ['10.21.170.242']  cbrcore-1[eth1]  ['10.21.170.241']
# 4  cbrcore-2[eth4]   ['10.10.184.22']  melcore-2[eth1]   ['10.10.184.21']
# 5  cbrcore-2[eth5]   ['10.20.139.45']     wagagg[eth0]   ['10.20.139.46']
#
# ess-sun
#        Interface               IPs Remote_Interface        Remote_IPs
# 0  ess-sun[eth0]  ['10.23.115.34']    eme-sun[eth0]  ['10.23.115.35']
# 1  ess-sun[eth0]  ['10.23.115.34']     sun-gw[eth0]  ['10.23.115.37']
#
# ungnodegw
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  ungnodegw[eth0]  ['10.25.166.102']   ungnode0[eth0]  ['10.25.166.117']
# 1  ungnodegw[eth1]   ['10.25.227.50']     wagagg[eth2]   ['10.25.227.35']
# 2  ungnodegw[eth2]  ['10.25.164.152']   ungnode2[eth0]    ['10.25.164.5']
# 3  ungnodegw[eth3]   ['10.25.165.95']   ungnode1[eth0]   ['10.25.165.10']
#
# wagnodec
#         Interface                IPs Remote_Interface         Remote_IPs
# 0  wagnodec[eth0]  ['10.24.145.208']     wagagg[eth3]  ['10.24.145.168']
# 1  wagnodec[eth1]  ['10.24.130.251']     wagagg[eth4]   ['10.24.131.11']
#
# meeknode0
#          Interface                IPs  Remote_Interface         Remote_IPs
# 0  meeknode0[eth0]  ['10.25.136.147']  meeknodegw[eth3]  ['10.25.136.212']
#
# eme-brd
#        Interface                IPs Remote_Interface         Remote_IPs
# 0  eme-brd[eth0]  ['10.23.180.211']     brd-gw[eth2]  ['10.23.180.214']
# 1  eme-brd[eth0]  ['10.23.180.211']    ess-brd[eth0]  ['10.23.180.209']
#
# cbrcore-1
#          Interface                IPs Remote_Interface         Remote_IPs
# 0  cbrcore-1[eth0]  ['10.22.167.225']     kng-gw[eth2]  ['10.22.167.226']
# 1  cbrcore-1[eth1]  ['10.21.170.241']  cbrcore-2[eth3]  ['10.21.170.242']
# 2  cbrcore-1[eth2]  ['10.10.139.225']  sydcore-1[eth5]  ['10.10.139.226']
# 3  cbrcore-1[eth3]  ['10.22.178.130']     brd-gw[eth1]  ['10.22.178.133']
# 4  cbrcore-1[eth4]  ['10.10.186.253']  melcore-1[eth3]  ['10.10.186.254']
# 5  cbrcore-1[eth5]  ['10.20.154.245']     wagagg[eth1]  ['10.20.154.246']
#
# cmtnode0
#         Interface               IPs Remote_Interface         Remote_IPs
# 0  cmtnode0[eth0]  ['10.25.152.93']  cmtnodegw[eth3]  ['10.25.152.118']
#
# rch-gw
#       Interface                IPs Remote_Interface         Remote_IPs
# 0  rch-gw[eth0]  ['10.23.196.180']    eme-rch[eth0]  ['10.23.196.181']
# 1  rch-gw[eth0]  ['10.23.196.180']    ess-rch[eth0]  ['10.23.196.177']
# 2  rch-gw[eth1]   ['10.22.223.90']  melcore-2[eth2]   ['10.22.223.93']
# 3  rch-gw[eth2]  ['10.22.213.170']  melcore-1[eth0]  ['10.22.213.173']
#
# dwncore-1
#          Interface               IPs Remote_Interface        Remote_IPs
# 0  dwncore-1[eth0]  ['10.22.85.105']     plm-gw[eth1]  ['10.22.85.107']
# 1  dwncore-1[eth1]  ['10.22.93.121']     nkr-gw[eth0]  ['10.22.93.123']
# 2  dwncore-1[eth2]   ['10.10.65.25']  bnecore-1[eth3]   ['10.10.65.26']
# 3  dwncore-1[eth3]  ['10.21.80.250']  dwncore-2[eth3]  ['10.21.80.249']
# 4  dwncore-1[eth4]  ['10.10.45.129']  percore-1[eth4]  ['10.10.45.130']
# 5  dwncore-1[eth5]    ['10.20.81.5']    tncragg[eth0]    ['10.20.81.6']
#
# meeknodegw
#           Interface                IPs Remote_Interface         Remote_IPs
# 0  meeknodegw[eth0]   ['10.25.202.31']    gdtnagg[eth4]  ['10.25.202.222']
# 1  meeknodegw[eth1]  ['10.25.137.183']  meeknode2[eth0]  ['10.25.137.132']
# 2  meeknodegw[eth2]  ['10.25.140.169']  meeknode1[eth0]  ['10.25.140.173']
# 3  meeknodegw[eth3]  ['10.25.136.212']  meeknode0[eth0]  ['10.25.136.147']
#
# nmnnode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  nmnnode1[eth0]  ['10.25.77.221']  nmnnodegw[eth2]  ['10.25.77.240']
#
# hoenode1
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  hoenode1[eth0]  ['10.25.161.89']  hoenodegw[eth1]  ['10.25.161.70']
#
# echnode0
#         Interface               IPs Remote_Interface        Remote_IPs
# 0  echnode0[eth0]  ['10.25.119.99']  echnodegw[eth2]  ['10.25.119.46']

# %%
# List references to undefined structures
bf.q.undefinedReferences().answer().frame()
# Out:
# Empty DataFrame
# Columns: [File_Name, Struct_Type, Ref_Name, Context, Lines]
# Index: []

# %%
# Get all edges 
bf.q.edges().answer().frame()
# Out:
#            Interface                IPs Remote_Interface         Remote_IPs
# 0    adlcore-1[eth0]    ['10.21.9.193']  adlcore-2[eth2]    ['10.21.9.194']
# 1    adlcore-1[eth1]   ['10.22.27.115']     tor-gw[eth2]   ['10.22.27.116']
# 2    adlcore-1[eth2]    ['10.22.11.73']     edn-gw[eth1]    ['10.22.11.75']
# 3    adlcore-1[eth3]    ['10.10.22.25']  percore-1[eth3]    ['10.10.22.26']
# 4    adlcore-1[eth4]   ['10.10.10.198']  melcore-1[eth2]   ['10.10.10.197']
# ..               ...                ...              ...                ...
# 387  wwanodegw[eth3]  ['10.25.160.146']   wwanode1[eth0]   ['10.25.160.57']
# 388     yrv-gw[eth0]  ['10.22.217.196']  melcore-2[eth3]  ['10.22.217.197']
# 389     yrv-gw[eth1]  ['10.22.221.181']  melcore-1[eth4]  ['10.22.221.180']
# 390     yrv-gw[eth2]  ['10.23.208.165']    eme-yrv[eth0]  ['10.23.208.164']
# 391     yrv-gw[eth2]  ['10.23.208.165']    ess-yrv[eth0]  ['10.23.208.161']
#
# [392 rows x 4 columns]

# %%
# Do a traceroute from host1 to 1.0.2.2
tr_frame = bf.q.traceroute(startLocation="adlcore-1", headers=HeaderConstraints(dstIps="10.25.15.38")).answer().frame()

# Display results using customizations to handle large string values

show(tr_frame)
# Out:
#                                                           Flow  \
# 0  start=adlcore-1 [10.10.10.198:49152->10.25.15.38:33434 UDP]
# 1   start=adlcore-1 [10.10.22.25:49152->10.25.15.38:33434 UDP]
# 2  start=adlcore-1 [10.20.12.133:49152->10.25.15.38:33434 UDP]
# 3   start=adlcore-1 [10.21.9.193:49152->10.25.15.38:33434 UDP]
# 4   start=adlcore-1 [10.22.11.73:49152->10.25.15.38:33434 UDP]
# 5  start=adlcore-1 [10.22.27.115:49152->10.25.15.38:33434 UDP]
# 6     start=adlcore-1 [127.0.0.1:49152->10.25.15.38:33434 UDP]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Traces  \
# 0  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 1  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 2  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 3  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 4  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 5  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
# 6  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth3 with resolved next-hop IP: 10.10.22.26, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth3 ip 10.10.22.26)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth3)), (RECEIVED(eth3), FORWARDED(Forwarded out interface: eth6 with resolved next-hop IP: 10.20.38.46, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth6 ip 10.20.38.46)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth6)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.25.205.112, Routes: [ospf (Network: 10.25.15.0/25, Next Hop: interface eth2 ip 10.25.205.112)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), ACCEPTED(eth1)))]
#
#   TraceCount
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1
# 6          1

# %%
# Fetch the routing table of all VRFs on all nodes in the snapshot
routes_all = bf.q.routes().answer().frame()

# %%
routes_all
# Out:
#             Node      VRF          Network                         Next_Hop  \
# 0      adlcore-1  default    10.10.2.96/30    interface eth0 ip 10.21.9.194
# 1      adlcore-1  default   10.10.9.204/30    interface eth0 ip 10.21.9.194
# 2      adlcore-1  default  10.10.10.196/30                   interface eth4
# 3      adlcore-1  default   10.10.22.24/30                   interface eth3
# 4      adlcore-1  default  10.10.45.128/30    interface eth3 ip 10.10.22.26
# ...          ...      ...              ...                              ...
# 12541     yrv-gw  default   10.25.243.0/25  interface eth0 ip 10.22.217.197
# 12542     yrv-gw  default   10.25.243.0/25  interface eth1 ip 10.22.221.180
# 12543     yrv-gw  default   10.25.250.0/25  interface eth0 ip 10.22.217.197
# 12544     yrv-gw  default   10.25.250.0/25  interface eth1 ip 10.22.221.180
# 12545     yrv-gw  default      127.0.0.0/8                     interface lo
#
#           Next_Hop_IP Next_Hop_Interface   Protocol Metric Admin_Distance  \
# 0         10.21.9.194               eth0       ospf     20            110
# 1         10.21.9.194               eth0       ospf     20            110
# 2      AUTO/NONE(-1l)               eth4  connected      0              0
# 3      AUTO/NONE(-1l)               eth3  connected      0              0
# 4         10.10.22.26               eth3       ospf     20            110
# ...               ...                ...        ...    ...            ...
# 12541   10.22.217.197               eth0       ospf     30            110
# 12542   10.22.221.180               eth1       ospf     30            110
# 12543   10.22.217.197               eth0       ospf     30            110
# 12544   10.22.221.180               eth1       ospf     30            110
# 12545  AUTO/NONE(-1l)                 lo  connected      0              0
#
#         Tag
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 12541  None
# 12542  None
# 12543  None
# 12544  None
# 12545  None
#
# [12546 rows x 10 columns]

# %%
# code that runs traceroutes from every node to every (relevant) IP address
interface_properties = bf.q.interfaceProperties(interfaces="/eth/", properties="Bandwidth,VRF,Primary_Address").answer().frame()
node_properties  = bf.q.nodeProperties(properties="Domain_Name,NTP_Servers,Interfaces").answer().frame()

traceroute_list = []
counter = 0

number_of_trials = 100

while counter < number_of_trials:
    node_name = random.choice(node_properties.Node)
    IP_address = random.choice(interface_properties.Primary_Address)
    traceroute_output = bf.q.traceroute(startLocation=node_name, headers=HeaderConstraints(dstIps=IP_address)).answer().frame()
    traceroute_list.append(traceroute_output)
    print(traceroute_output.Traces[0][0].disposition)
    counter +=1
# Out:
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# NEIGHBOR_UNREACHABLE
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK

# %%
for i in range(9):
    print(traceroute_list[i].Traces[0][0].disposition)
# Out:
# DENIED_OUT
# DENIED_OUT
# EXITS_NETWORK
# EXITS_NETWORK
# DENIED_OUT
# NEIGHBOR_UNREACHABLE
# EXITS_NETWORK
# NEIGHBOR_UNREACHABLE
# DENIED_OUT

# %%
traceroute_list[]
# Out:
#                                                         Flow  \
# 0  start=ess-sun [10.23.115.34:49152->10.24.120.0:33434 UDP]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Traces  \
# 0  [((ORIGINATED(default), FORWARDED(Forwarded out interface: eth0 with resolved next-hop IP: 10.23.115.37, Routes: [static (Network: 0.0.0.0/0, Next Hop: interface eth0 ip 10.23.115.37)]), PERMITTED(filter::OUTPUT (EGRESS_FILTER)), TRANSMITTED(eth0)), (RECEIVED(eth0), FORWARDED(Forwarded out interface: eth1 with resolved next-hop IP: 10.22.126.109, Routes: [ospf (Network: 10.24.120.0/24, Next Hop: interface eth1 ip 10.22.126.109)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth1)), (RECEIVED(eth0), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.20.99.62, Routes: [ospf (Network: 10.24.120.0/24, Next Hop: interface eth2 ip 10.20.99.62)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), FORWARDED(Forwarded out interface: eth5, Routes: [connected (Network: 10.24.120.0/24, Next Hop: interface eth5)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth5), EXITS_NETWORK(Output Interface: eth5, Resolved Next Hop IP: 10.24.120.0))), ((ORIGINATED(default), FORWARDED(Forwarded out interface: eth0 with resolved next-hop IP: 10.23.115.37, Routes: [static (Network: 0.0.0.0/0, Next Hop: interface eth0 ip 10.23.115.37)]), PERMITTED(filter::OUTPUT (EGRESS_FILTER)), TRANSMITTED(eth0)), (RECEIVED(eth0), FORWARDED(Forwarded out interface: eth2 with resolved next-hop IP: 10.22.115.230, Routes: [ospf (Network: 10.24.120.0/24, Next Hop: interface eth2 ip 10.22.115.230)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth2)), (RECEIVED(eth0), FORWARDED(Forwarded out interface: eth5 with resolved next-hop IP: 10.20.98.65, Routes: [ospf (Network: 10.24.120.0/24, Next Hop: interface eth5 ip 10.20.98.65)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth5)), (RECEIVED(eth1), FORWARDED(Forwarded out interface: eth5, Routes: [connected (Network: 10.24.120.0/24, Next Hop: interface eth5)]), PERMITTED(filter::FORWARD (EGRESS_FILTER)), TRANSMITTED(eth5), EXITS_NETWORK(Output Interface: eth5, Resolved Next Hop IP: 10.24.120.0)))]
#
#   TraceCount
# 0          2
